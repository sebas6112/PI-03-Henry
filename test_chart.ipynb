# %%
import matplotlib.pyplot as plt  # para gráficas
import seaborn as sns  # para gráficas
import plotly.express as px  # gráficos interactivos
import numpy as np  # análisis de datos
import pandas as pd  # manipulación de datos
import Acquisition.request as request # funciones para conectarse a la api

# %%
pd = request.actual_data()

# %%
pd.index.values
# Out:
# array(['1INCH-PERP', '1INCH-0930', '1INCH-1230', '1INCH/USD', 'AAPL-0930',
#        'AAPL-1230', 'AAPL/USD', 'AAVE-PERP', 'AAVE-0930', 'AAVE-1230',
#        'AAVE/USD', 'AAVE/USDT', 'ABNB-0930', 'ABNB-1230', 'ABNB/USD',
#        'ACB-0930', 'ACB-1230', 'ACB/USD', 'ADA-PERP', 'ADA-0930',
#        'ADA-1230', 'AGLD-PERP', 'AGLD/USD', 'AKRO/USD', 'AKRO/USDT',
#        'ALCX-PERP', 'ALCX/USD', 'ALEPH/USD', 'ALGO-PERP', 'ALGO-0930',
#        'ALGO-1230', 'ALGO/USD', 'ALGO/USDT', 'ALICE-PERP', 'ALICE/USD',
#        'ALPHA-PERP', 'ALPHA/USD', 'ALT-PERP', 'ALT-0930', 'ALT-1230',
#        'AMC-0930', 'AMC-1230', 'AMC/USD', 'AMD-0930', 'AMD-1230',
#        'AMD/USD', 'AMPL-PERP', 'AMPL/USD', 'AMPL/USDT', 'AMZN-0930',
#        'AMZN-1230', 'AMZN/USD', 'APE-PERP', 'APE-0930', 'APE-1230',
#        'APE/USD', 'APEAMC/USD', 'APHA/USD', 'AR-PERP', 'ARKK-0930',
#        'ARKK-1230', 'ARKK/USD', 'ASD-PERP', 'ASD/USD', 'ATLAS-PERP',
#        'ATLAS/USD', 'ATOM-PERP', 'ATOM-0930', 'ATOM-1230', 'ATOM/USD',
#        'ATOM/USDT', 'AUDIO-PERP', 'AUDIO/USD', 'AUDIO/USDT', 'AURY/USD',
#        'AVAX-PERP', 'AVAX-0930', 'AVAX-1230', 'AVAX/BTC', 'AVAX/JPY',
#        'AVAX/USD', 'AVAX/USDT', 'AXS-PERP', 'AXS-0930', 'AXS-1230',
#        'AXS/USD', 'BABA-0930', 'BABA-1230', 'BABA/USD', 'BADGER-PERP',
#        'BADGER/USD', 'BAL-PERP', 'BAL-0930', 'BAL-1230', 'BAL/USD',
#        'BAL/USDT', 'BAND-PERP', 'BAND/USD', 'BAO/USD', 'BAR/USD',
#        'BAT-PERP', 'BAT/JPY', 'BAT/USD', 'BB-0930', 'BB-1230', 'BB/USD',
#        'BCH-PERP', 'BCH-0930', 'BCH-1230', 'BCH/BTC', 'BCH/JPY',
#        'BCH/USD', 'BCH/USDT', 'BICO/USD', 'BILI-0930', 'BILI-1230',
#        'BILI/USD', 'BIT-PERP', 'BIT/USD', 'BITO-0930', 'BITO-1230',
#        'BITO/USD', 'BITW-0930', 'BITW-1230', 'BITW/USD', 'BLT/USD',
#        'BNB-PERP', 'BNB-0930', 'BNB-1230', 'BNB/BTC', 'BNB/USD',
#        'BNB/USDT', 'BNT-PERP', 'BNT/USD', 'BNTX-0930', 'BNTX-1230',
#        'BNTX/USD', 'BOBA-PERP', 'BOBA/USD', 'BOLSONARO2022', 'BRZ-PERP',
#        'BRZ/USD', 'BRZ/USDT', 'BSV-PERP', 'BSV-0930', 'BSV-1230',
#        'BTC-PERP', 'BTC-MOVE-0928', 'BTC-MOVE-0929', 'BTC-0930',
#        'BTC-MOVE-2022Q3', 'BTC-MOVE-WK-0930', 'BTC-MOVE-WK-1007',
#        'BTC-MOVE-WK-1014', 'BTC-MOVE-WK-1021', 'BTC-1230',
#        'BTC-MOVE-2022Q4', 'BTC-0331', 'BTC/AUD', 'BTC/BRZ', 'BTC/EUR',
#        'BTC/JPY', 'BTC/TRYB', 'BTC/USD', 'BTC/USDT', 'BTT-PERP',
#        'BTT/USD', 'BYND-0930', 'BYND-1230', 'BYND/USD', 'C98-PERP',
#        'C98/USD', 'CAD/USD', 'CAKE-PERP', 'CEL-PERP', 'CEL-0930',
#        'CEL-1230', 'CEL/BTC', 'CEL/USD', 'CELO-PERP', 'CGC-0930',
#        'CGC-1230', 'CGC/USD', 'CHR-PERP', 'CHR/USD', 'CHZ-PERP',
#        'CHZ-0930', 'CHZ-1230', 'CHZ/USD', 'CHZ/USDT', 'CITY/USD',
#        'CLV-PERP', 'CLV/USD', 'COIN/USD', 'COMP-PERP', 'COMP-0930',
#        'COMP-1230', 'COMP/USD', 'COMP/USDT', 'CONV/USD', 'COPE/USD',
#        'CQT/USD', 'CREAM-PERP', 'CREAM/USD', 'CREAM/USDT', 'CRO-PERP',
#        'CRO/USD', 'CRON-0930', 'CRON-1230', 'CRON/USD', 'CRV-PERP',
#        'CRV/USD', 'CTX/USD', 'CTX/USDT', 'CUSDT/USD', 'CUSDT/USDT',
#        'CVC-PERP', 'CVC/USD', 'CVX-PERP', 'CVX/USD', 'DAI/USD',
#        'DAI/USDT', 'DASH-PERP', 'DAWN-PERP', 'DAWN/USD', 'DEFI-PERP',
#        'DEFI-0930', 'DEFI-1230', 'DENT-PERP', 'DENT/USD', 'DFL/USD',
#        'DKNG-0930', 'DKNG-1230', 'DKNG/USD', 'DMG/USD', 'DMG/USDT',
#        'DODO-PERP', 'DODO/USD', 'DOGE-PERP', 'DOGE-0930', 'DOGE-1230',
#        'DOGE/BTC', 'DOGE/JPY', 'DOGE/USD', 'DOGE/USDT', 'DOT-PERP',
#        'DOT-0930', 'DOT-1230', 'DOT/BTC', 'DOT/JPY', 'DOT/USD',
#        'DOT/USDT', 'DRGN-PERP', 'DYDX-PERP', 'DYDX/USD', 'EDEN-PERP',
#        'EDEN/USD', 'EGLD-PERP', 'EMB/USD', 'ENJ-PERP', 'ENJ/JPY',
#        'ENJ/USD', 'ENS-PERP', 'ENS/USD', 'EOS-PERP', 'EOS-0930',
#        'EOS-1230', 'ETC-PERP', 'ETH-PERP', 'ETH-0930', 'ETH-1230',
#        'ETH-0331', 'ETH/AUD', 'ETH/BRZ', 'ETH/BTC', 'ETH/EUR', 'ETH/JPY',
#        'ETH/USD', 'ETH/USDT', 'ETHE-0930', 'ETHE-1230', 'ETHE/USD',
#        'ETHW-PERP', 'ETHW/USD', 'EUL/USD', 'EUR/USD', 'EURT/EUR',
#        'EURT/USD', 'EURT/USDT', 'EXCH-PERP', 'EXCH-0930', 'EXCH-1230',
#        'FB-0930', 'FB-1230', 'FB/USD', 'FIDA-PERP', 'FIDA/USD',
#        'FIDA/USDT', 'FIL-PERP', 'FIL-0930', 'FIL-1230', 'FLM-PERP',
#        'FLOW-PERP', 'FLUX-PERP', 'FRONT/USD', 'FRONT/USDT', 'FTM-PERP',
#        'FTM-0930', 'FTM-1230', 'FTM/USD', 'FTT-PERP', 'FTT/BTC',
#        'FTT/JPY', 'FTT/USD', 'FTT/USDT', 'FXS-PERP', 'FXS/USD',
#        'GAL-PERP', 'GAL/USD', 'GALA-PERP', 'GALA/USD', 'GALFAN/USD',
#        'GARI/USD', 'GBP/USD', 'GBTC-0930', 'GBTC-1230', 'GBTC/USD',
#        'GDX-0930', 'GDX-1230', 'GDX/USD', 'GDXJ-0930', 'GDXJ-1230',
#        'GDXJ/USD', 'GENE/USD', 'GLD-0930', 'GLD-1230', 'GLD/USD',
#        'GLMR-PERP', 'GLXY/USD', 'GME-0930', 'GME-1230', 'GME/USD',
#        'GMT-PERP', 'GMT-0930', 'GMT-1230', 'GMT/USD', 'GODS/USD',
#        'GOG/USD', 'GOOGL-0930', 'GOOGL-1230', 'GOOGL/USD', 'GRT-PERP',
#        'GRT-0930', 'GRT-1230', 'GRT/USD', 'GST-PERP', 'GST-0930',
#        'GST/USD', 'GST/USDT', 'GT/USD', 'HBAR-PERP', 'HBB/USD',
#        'HGET/USD', 'HGET/USDT', 'HMT/USD', 'HNT-PERP', 'HNT/USD',
#        'HNT/USDT', 'HOLY-PERP', 'HOLY/USD', 'HOOD/USD', 'HOT-PERP',
#        'HT-PERP', 'HT/USD', 'HUM/USD', 'HXRO/USD', 'HXRO/USDT',
#        'ICP-PERP', 'ICX-PERP', 'IMX-PERP', 'IMX/USD', 'INDI/USD',
#        'INTER/USD', 'IOST-PERP', 'IOTA-PERP', 'IP3/USD', 'JASMY-PERP',
#        'JET/USD', 'JOE/USD', 'JST/USD', 'KAVA-PERP', 'KBTT-PERP',
#        'KBTT/USD', 'KIN/USD', 'KLUNC-PERP', 'KNC-PERP', 'KNC/USD',
#        'KNC/USDT', 'KSHIB-PERP', 'KSHIB/USD', 'KSM-PERP', 'KSOS-PERP',
#        'KSOS/USD', 'LDO-PERP', 'LDO/USD', 'LEO-PERP', 'LEO/USD',
#        'LINA-PERP', 'LINA/USD', 'LINK-PERP', 'LINK-0930', 'LINK-1230',
#        'LINK/BTC', 'LINK/USD', 'LINK/USDT', 'LOOKS-PERP', 'LOOKS/USD',
#        'LRC-PERP', 'LRC/USD', 'LTC-PERP', 'LTC-0930', 'LTC-1230',
#        'LTC/BTC', 'LTC/JPY', 'LTC/USD', 'LTC/USDT', 'LUA/USD', 'LUA/USDT',
#        'LUNA2-PERP', 'LUNC-PERP', 'MANA-PERP', 'MANA/USD', 'MAPS-PERP',
#        'MAPS/USD', 'MAPS/USDT', 'MATH/USD', 'MATH/USDT', 'MATIC-PERP',
#        'MATIC-1230', 'MATIC/BTC', 'MATIC/USD', 'MBS/USD', 'MCB/USD',
#        'MEDIA-PERP', 'MEDIA/USD', 'MER/USD', 'MID-PERP', 'MID-0930',
#        'MID-1230', 'MINA-PERP', 'MKR-PERP', 'MKR/USD', 'MKR/USDT',
#        'MNGO-PERP', 'MNGO/USD', 'MOB-PERP', 'MOB/USD', 'MOB/USDT',
#        'MPLX/USD', 'MRNA-0930', 'MRNA-1230', 'MRNA/USD', 'MSOL/USD',
#        'MSTR-0930', 'MSTR-1230', 'MSTR/USD', 'MTA/USD', 'MTA/USDT',
#        'MTL-PERP', 'MTL/USD', 'MVDA10-PERP', 'MVDA25-PERP', 'NEAR-PERP',
#        'NEAR-1230', 'NEAR/USD', 'NEAR/USDT', 'NEO-PERP', 'NEXO/USD',
#        'NFLX-0930', 'NFLX-1230', 'NFLX/USD', 'NIO-0930', 'NIO-1230',
#        'NIO/USD', 'NOK-0930', 'NOK-1230', 'NOK/USD', 'NVDA-0930',
#        'NVDA-1230', 'NVDA/USD', 'OKB-PERP', 'OKB-0930', 'OKB-1230',
#        'OKB/USD', 'OMG-PERP', 'OMG-0930', 'OMG-1230', 'OMG/JPY',
#        'OMG/USD', 'ONE-PERP', 'ONT-PERP', 'OP-PERP', 'OP-0930', 'OP-1230',
#        'ORBS/USD', 'ORCA/USD', 'OXY-PERP', 'OXY/USD', 'OXY/USDT',
#        'PAXG-PERP', 'PAXG/USD', 'PAXG/USDT', 'PENN-0930', 'PENN-1230',
#        'PENN/USD', 'PEOPLE-PERP', 'PEOPLE/USD', 'PERP-PERP', 'PERP/USD',
#        'PFE-0930', 'PFE-1230', 'PFE/USD', 'POLIS-PERP', 'POLIS/USD',
#        'PORT/USD', 'TRUMP2024', 'PRISM/USD', 'PRIV-PERP', 'PRIV-0930',
#        'PRIV-1230', 'PROM-PERP', 'PROM/USD', 'PSG/USD', 'PSY/USD',
#        'PTU/USD', 'PUNDIX-PERP', 'PUNDIX/USD', 'PYPL-0930', 'PYPL-1230',
#        'PYPL/USD', 'QI/USD', 'QTUM-PERP', 'RAY-PERP', 'RAY/USD',
#        'REAL/USD', 'REEF-PERP', 'REEF/USD', 'REN-PERP', 'REN/USD',
#        'RNDR-PERP', 'RNDR/USD', 'RON-PERP', 'ROOK/USD', 'ROOK/USDT',
#        'ROSE-PERP', 'RSR-PERP', 'RSR/USD', 'RUNE-PERP', 'RVN-PERP',
#        'SAND-PERP', 'SAND/USD', 'SC-PERP', 'SCRT-PERP', 'SECO-PERP',
#        'SECO/USD', 'SHIB-PERP', 'SHIB/USD', 'SHIT-PERP', 'SHIT-0930',
#        'SHIT-1230', 'SKL-PERP', 'SKL/USD', 'SLND/USD', 'SLP-PERP',
#        'SLP/USD', 'SLRS/USD', 'SLV-0930', 'SLV-1230', 'SLV/USD',
#        'SNX-PERP', 'SNX/USD', 'SNY/USD', 'SOL-PERP', 'SOL-0930',
#        'SOL-1230', 'SOL/BTC', 'SOL/JPY', 'SOL/USD', 'SOL/USDT',
#        'SOS-PERP', 'SOS/USD', 'SPA/USD', 'SPELL-PERP', 'SPELL/USD',
#        'SPY-0930', 'SPY-1230', 'SPY/USD', 'SQ-0930', 'SQ-1230', 'SQ/USD',
#        'SRM-PERP', 'SRM/USD', 'SRM/USDT', 'STARS/USD', 'STEP-PERP',
#        'STEP/USD', 'STETH/USD', 'STG-PERP', 'STG/USD', 'STMX-PERP',
#        'STMX/USD', 'STORJ-PERP', 'STORJ/USD', 'STSOL/USD', 'STX-PERP',
#        'SUN/USD', 'SUSHI-PERP', 'SUSHI-0930', 'SUSHI-1230', 'SUSHI/BTC',
#        'SUSHI/USD', 'SUSHI/USDT', 'SWEAT/USD', 'SXP-PERP', 'SXP-0930',
#        'SXP-1230', 'SXP/BTC', 'SXP/USD', 'SXP/USDT', 'THETA-PERP',
#        'TLM-PERP', 'TLM/USD', 'TLRY-0930', 'TLRY-1230', 'TLRY/USD',
#        'TOMO-PERP', 'TOMO/USD', 'TOMO/USDT', 'TONCOIN-PERP',
#        'TONCOIN/USD', 'TRU-PERP', 'TRU/USD', 'TRU/USDT', 'TRX-PERP',
#        'TRX-0930', 'TRX-1230', 'TRX/BTC', 'TRX/USD', 'TRX/USDT',
#        'TRYB-PERP', 'TRYB/USD', 'TSLA-0930', 'TSLA-1230', 'TSLA/BTC',
#        'TSLA/DOGE', 'TSLA/USD', 'TSM-0930', 'TSM-1230', 'TSM/USD',
#        'TULIP/USD', 'TWTR-0930', 'TWTR-1230', 'TWTR/USD', 'UBER-0930',
#        'UBER-1230', 'UBER/USD', 'UBXT/USD', 'UBXT/USDT', 'UMEE/USD',
#        'UNI-PERP', 'UNI-0930', 'UNI-1230', 'UNI/BTC', 'UNI/USD',
#        'UNI/USDT', 'UNISWAP-PERP', 'UNISWAP-0930', 'UNISWAP-1230',
#        'USD/JPY', 'USDT-PERP', 'USDT-0930', 'USDT-1230', 'USDT/USD',
#        'USO-0930', 'USO-1230', 'USO/USD', 'USTC-PERP', 'VET-PERP',
#        'VGX/USD', 'WAVES-PERP', 'WAVES-0930', 'WAVES-1230', 'WAVES/USD',
#        'WBTC/BTC', 'WBTC/USD', 'WFLOW/USD', 'WNDR/USD', 'WRX/USD',
#        'WRX/USDT', 'WSB-0930', 'WSB-1230', 'XAUT-PERP', 'XAUT/USD',
#        'XAUT/USDT', 'XEM-PERP', 'XLM-PERP', 'XMR-PERP', 'XRP-PERP',
#        'XRP-0930', 'XRP-1230', 'XRP/BTC', 'XRP/JPY', 'XRP/USD',
#        'XRP/USDT', 'XTZ-PERP', 'XTZ-0930', 'XTZ-1230', 'YFI-PERP',
#        'YFI-0930', 'YFI-1230', 'YFI/BTC', 'YFI/USD', 'YFI/USDT',
#        'YFII-PERP', 'YFII/USD', 'YGG/USD', 'ZEC-PERP', 'ZIL-PERP',
#        'ZM-0930', 'ZM-1230', 'ZM/USD', 'ZRX-PERP', 'ZRX/USD',
#        'ADABEAR/USD', 'ADABULL/USD', 'ADAHALF/USD', 'ADAHEDGE/USD',
#        'ALGOBEAR/USD', 'ALGOBULL/USD', 'ALGOHALF/USD', 'ALGOHEDGE/USD',
#        'ALTBEAR/USD', 'ALTBULL/USD', 'ALTHALF/USD', 'ALTHEDGE/USD',
#        'ASDBEAR/USD', 'ASDBEAR/USDT', 'ASDBULL/USD', 'ASDBULL/USDT',
#        'ASDHALF/USD', 'ASDHEDGE/USD', 'ATOMBEAR/USD', 'ATOMBULL/USD',
#        'ATOMHALF/USD', 'ATOMHEDGE/USD', 'BALBEAR/USD', 'BALBEAR/USDT',
#        'BALBULL/USD', 'BALBULL/USDT', 'BALHALF/USD', 'BALHEDGE/USD',
#        'BCHBEAR/USD', 'BCHBEAR/USDT', 'BCHBULL/USD', 'BCHBULL/USDT',
#        'BCHHALF/USD', 'BCHHEDGE/USD', 'BEAR/USD', 'BEAR/USDT',
#        'BEARSHIT/USD', 'BNBBEAR/USD', 'BNBBEAR/USDT', 'BNBBULL/USD',
#        'BNBBULL/USDT', 'BNBHALF/USD', 'BNBHEDGE/USD', 'BSVBEAR/USD',
#        'BSVBEAR/USDT', 'BSVBULL/USD', 'BSVBULL/USDT', 'BSVHALF/USD',
#        'BSVHEDGE/USD', 'BULL/USD', 'BULL/USDT', 'BULLSHIT/USD',
#        'BVOL/USD', 'COMPBEAR/USD', 'COMPBEAR/USDT', 'COMPBULL/USD',
#        'COMPBULL/USDT', 'COMPHALF/USD', 'COMPHEDGE/USD', 'DEFIBEAR/USD',
#        'DEFIBEAR/USDT', 'DEFIBULL/USD', 'DEFIBULL/USDT', 'DEFIHALF/USD',
#        'DEFIHEDGE/USD', 'DOGEBEAR2021/USD', 'DOGEBULL/USD',
#        'DOGEHALF/USD', 'DOGEHEDGE/USD', 'DRGNBEAR/USD', 'DRGNBULL/USD',
#        'DRGNHALF/USD', 'DRGNHEDGE/USD', 'EOSBEAR/USD', 'EOSBEAR/USDT',
#        'EOSBULL/USD', 'EOSBULL/USDT', 'EOSHALF/USD', 'EOSHEDGE/USD',
#        'ETCBEAR/USD', 'ETCBULL/USD', 'ETCHALF/USD', 'ETCHEDGE/USD',
#        'ETHBEAR/USD', 'ETHBEAR/USDT', 'ETHBULL/USD', 'ETHBULL/USDT',
#        'ETHHALF/USD', 'ETHHEDGE/USD', 'EXCHBEAR/USD', 'EXCHBULL/USD',
#        'EXCHHALF/USD', 'EXCHHEDGE/USD', 'GRTBEAR/USD', 'GRTBULL/USD',
#        'HALF/USD', 'HALFSHIT/USD', 'HEDGE/USD', 'HEDGESHIT/USD',
#        'HTBEAR/USD', 'HTBULL/USD', 'HTHALF/USD', 'HTHEDGE/USD',
#        'IBVOL/USD', 'KNCBEAR/USD', 'KNCBEAR/USDT', 'KNCBULL/USD',
#        'KNCBULL/USDT', 'KNCHALF/USD', 'KNCHEDGE/USD', 'LEOBEAR/USD',
#        'LEOBULL/USD', 'LEOHALF/USD', 'LEOHEDGE/USD', 'LINKBEAR/USD',
#        'LINKBEAR/USDT', 'LINKBULL/USD', 'LINKBULL/USDT', 'LINKHALF/USD',
#        'LINKHEDGE/USD', 'LTCBEAR/USD', 'LTCBEAR/USDT', 'LTCBULL/USD',
#        'LTCBULL/USDT', 'LTCHALF/USD', 'LTCHEDGE/USD', 'MATICBEAR2021/USD',
#        'MATICBULL/USD', 'MATICHALF/USD', 'MATICHEDGE/USD', 'MIDBEAR/USD',
#        'MIDBULL/USD', 'MIDHALF/USD', 'MIDHEDGE/USD', 'MKRBEAR/USD',
#        'MKRBULL/USD', 'OKBBEAR/USD', 'OKBBULL/USD', 'OKBHALF/USD',
#        'OKBHEDGE/USD', 'PAXGBEAR/USD', 'PAXGBULL/USD', 'PAXGHALF/USD',
#        'PAXGHEDGE/USD', 'PRIVBEAR/USD', 'PRIVBULL/USD', 'PRIVHALF/USD',
#        'PRIVHEDGE/USD', 'SUSHIBEAR/USD', 'SUSHIBULL/USD', 'SXPBEAR/USD',
#        'SXPBULL/USD', 'SXPHALF/USD', 'SXPHALF/USDT', 'SXPHEDGE/USD',
#        'THETABEAR/USD', 'THETABULL/USD', 'THETAHALF/USD',
#        'THETAHEDGE/USD', 'TOMOBEAR2021/USD', 'TOMOBULL/USD',
#        'TOMOHALF/USD', 'TOMOHEDGE/USD', 'TRXBEAR/USD', 'TRXBULL/USD',
#        'TRXHALF/USD', 'TRXHEDGE/USD', 'TRYBBEAR/USD', 'TRYBBULL/USD',
#        'TRYBHALF/USD', 'TRYBHEDGE/USD', 'UNISWAPBEAR/USD',
#        'UNISWAPBULL/USD', 'USDTBEAR/USD', 'USDTBULL/USD', 'USDTHALF/USD',
#        'USDTHEDGE/USD', 'VETBEAR/USD', 'VETBEAR/USDT', 'VETBULL/USD',
#        'VETBULL/USDT', 'VETHEDGE/USD', 'XAUTBEAR/USD', 'XAUTBULL/USD',
#        'XAUTHALF/USD', 'XAUTHEDGE/USD', 'XLMBEAR/USD', 'XLMBULL/USD',
#        'XRPBEAR/USD', 'XRPBEAR/USDT', 'XRPBULL/USD', 'XRPBULL/USDT',
#        'XRPHALF/USD', 'XRPHEDGE/USD', 'XTZBEAR/USD', 'XTZBEAR/USDT',
#        'XTZBULL/USD', 'XTZBULL/USDT', 'XTZHALF/USD', 'XTZHEDGE/USD',
#        'ZECBEAR/USD', 'ZECBULL/USD'], dtype=object)

# %%
request.individual('XLMBEAR/USD')
# Out:
# ask                          0.01023
# baseCurrency                 XLMBEAR
# bid                         0.010072
# change1h                   -0.008481
# change24h                   0.040427
# changeBod                   0.043345
# enabled                         True
# futureType                      None
# highLeverageFeeExempt           True
# isEtfMarket                     True
# largeOrderThreshold            280.0
# last                        0.010882
# minProvideSize                  10.0
# name                     XLMBEAR/USD
# postOnly                       False
# price                        0.01023
# priceHigh24h                0.010882
# priceIncrement              0.000003
# priceLow24h                 0.009575
# quoteCurrency                    USD
# quoteVolume24h            118.740375
# restricted                     False
# sizeIncrement                   10.0
# type                            spot
# underlying                      None
# volumeUsd24h              118.740375
# Name: result, dtype: object
