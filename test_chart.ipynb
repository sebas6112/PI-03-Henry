# %%
import matplotlib.pyplot as plt  # para gráficas
import seaborn as sns  # para gráficas
import plotly.express as px  # gráficos interactivos
import numpy as np  # análisis de datos
import pandas as pd  # manipulación de datos
import Acquisition.request as request # funciones para conectarse a la api

# %%
df = request.actual_data()
df.head()
# Out:
#          name  enabled  postOnly  priceIncrement  sizeIncrement  \
# 0  1INCH-PERP     True     False          0.0001           1.00
# 1  1INCH-0930     True     False          0.0001           1.00
# 2  1INCH-1230     True     False          0.0001           1.00
# 3   1INCH/USD     True     False          0.0001           1.00
# 4   AAPL-0930     True     False          0.0100           0.01
#
#    minProvideSize      last       bid       ask     price  ...  \
# 0            1.00    0.5890    0.5887    0.5890    0.5890  ...
# 1            1.00    0.5881    0.5847    0.5881    0.5881  ...
# 2            1.00    0.5714    0.5680    0.5707    0.5707  ...
# 3            1.00    0.5888    0.5887    0.5891    0.5888  ...
# 4            0.01  150.1500  148.6000  150.6300  150.1500  ...
#
#   highLeverageFeeExempt largeOrderThreshold  change1h  change24h changeBod  \
# 0                 False               350.0  0.003578  -0.022082 -0.031728
# 1                 False               350.0  0.001874  -0.019507 -0.026002
# 2                 False               350.0  0.003340  -0.022439 -0.032220
# 3                  True               280.0  0.002383  -0.022739 -0.032693
# 4                 False               350.0  0.000400  -0.012171 -0.012171
#
#   quoteVolume24h  volumeUsd24h  priceHigh24h  priceLow24h  tokenizedEquity
# 0   4.175733e+06  4.175733e+06        0.6121       0.5744              NaN
# 1   9.628234e+03  9.628234e+03        0.6084       0.5720              NaN
# 2   1.002465e+04  1.002465e+04        0.5910       0.5564              NaN
# 3   1.550742e+06  1.550742e+06        0.6126       0.5745              NaN
# 4   9.517949e+04  9.517949e+04      152.0100     145.1300             True
#
# [5 rows x 27 columns]

# %%
df[df.name.str.contains('MATIC')]
# Out:
#                   name  enabled  postOnly  priceIncrement  sizeIncrement  \
# 437         MATIC-PERP     True     False    2.500000e-06       1.000000
# 438         MATIC-1230     True     False    2.500000e-06       1.000000
# 439          MATIC/BTC     True     False    1.000000e-08      10.000000
# 440          MATIC/USD     True     False    1.000000e-06      10.000000
# 859  MATICBEAR2021/USD     True     False    1.000000e-08   10000.000000
# 860      MATICBULL/USD     True     False    1.000000e-07    1000.000000
# 861      MATICHALF/USD     True     False    5.000000e+00       0.000001
# 862     MATICHEDGE/USD     True     False    1.000000e-05       1.000000
#
#      minProvideSize          last           bid           ask         price  \
# 437        1.000000      0.753230      0.753230      0.753232      0.753230
# 438        1.000000      0.734012      0.735052      0.739017      0.735052
# 439       10.000000      0.000038      0.000038      0.000038      0.000038
# 440       10.000000      0.753564      0.753075      0.753361      0.753361
# 859    10000.000000      0.000021      0.000021      0.000021      0.000021
# 860     1000.000000      0.000271      0.000271      0.000272      0.000271
# 861        0.000001  67970.000000  67585.000000  67810.000000  67810.000000
# 862        1.000000      0.114570      0.113720      0.114380      0.114380
#
#      ... highLeverageFeeExempt largeOrderThreshold  change1h  change24h  \
# 437  ...                 False              2500.0  0.004307   0.019863
# 438  ...                 False              2500.0  0.000538   0.014852
# 439  ...                  True              1200.0 -0.004683  -0.016200
# 440  ...                  True              2000.0  0.004077   0.019150
# 859  ...                  True               280.0 -0.020446  -0.061024
# 860  ...                  True               280.0  0.007804   0.060618
# 861  ...                  True               280.0  0.001921   0.010431
# 862  ...                  True               280.0 -0.001658  -0.014984
#
#     changeBod quoteVolume24h  volumeUsd24h  priceHigh24h   priceLow24h  \
# 437  0.019342   4.725400e+07  4.725400e+07      0.754663      0.711710
# 438  0.015764   1.127793e+04  1.127793e+04      0.737650      0.697500
# 439 -0.012135   2.684988e+00  5.283153e+04      0.000039      0.000038
# 440  0.019099   9.465485e+06  9.465485e+06      0.754269      0.712279
# 859 -0.058508   3.985724e+04  3.985724e+04      0.000025      0.000021
# 860  0.055253   1.198108e+05  1.198108e+05      0.000272      0.000229
# 861  0.009979   0.000000e+00  0.000000e+00  67970.000000  66015.000000
# 862 -0.013881   5.542895e+02  5.542895e+02      0.120020      0.114170
#
#      tokenizedEquity
# 437              NaN
# 438              NaN
# 439              NaN
# 440              NaN
# 859              NaN
# 860              NaN
# 861              NaN
# 862              NaN
#
# [8 rows x 27 columns]

# %%
markets_to_use = ['BTC/USD', 'ETH/USD', 'USDT/USD', 'BNB/USD', 'XRP/USD', 'SOL/USD', 'DOGE/USD', 'DOT/USD', 'DAI/USD', 'MATIC/USD']

# %%
markets_to_use = ['BTC/USD', 'ETH/USD', 'USDT/USD', 'BNB/USD', 'XRP/USD', 'SOL/USD', 'DOGE/USD', 'DOT/USD', 'DAI/USD', 'MATIC/USD']
df = request.actual_data()
df = df[df.name.isin(markets_to_use)]
df.reset_index(drop=True, inplace=True)
df
# Out:
#         name  enabled  postOnly  priceIncrement  sizeIncrement  \
# 0    BNB/USD     True     False    1.000000e-03         0.0100
# 1    BTC/USD     True     False    1.000000e+00         0.0001
# 2    DAI/USD     True     False    1.000000e-04         0.1000
# 3   DOGE/USD     True     False    5.000000e-07         1.0000
# 4    DOT/USD     True     False    1.000000e-03         0.1000
# 5    ETH/USD     True     False    1.000000e-01         0.0010
# 6  MATIC/USD     True     False    1.000000e-06        10.0000
# 7    SOL/USD     True     False    2.500000e-03         0.0100
# 8   USDT/USD     True     False    1.000000e-04         0.0100
# 9    XRP/USD     True     False    2.500000e-05         1.0000
#
#    minProvideSize          last           bid           ask         price  \
# 0          0.0100    281.845000    281.810000    281.817000    281.817000
# 1          0.0001  19538.000000  19538.000000  19539.000000  19538.000000
# 2          0.1000      0.999800      0.999800      0.999900      0.999800
# 3          1.0000      0.060506      0.060494      0.060507      0.060506
# 4          0.1000      6.400000      6.400000      6.402000      6.400000
# 5          0.0010   1340.100000   1340.000000   1340.100000   1340.100000
# 6         10.0000      0.748980      0.748439      0.748680      0.748680
# 7          0.0100     33.280000     33.280000     33.282500     33.280000
# 8          0.0100      0.999900      0.999800      0.999900      0.999900
# 9          1.0000      0.448175      0.448125      0.448200      0.448175
#
#    ... highLeverageFeeExempt largeOrderThreshold  change1h  change24h  \
# 0  ...                  True              2000.0 -0.005168   0.033921
# 1  ...                  True              2400.0 -0.008727   0.025724
# 2  ...                  True               280.0  0.000000  -0.000200
# 3  ...                  True              2000.0 -0.007504   0.000438
# 4  ...                  True              2000.0 -0.005594   0.003922
# 5  ...                  True              2400.0 -0.010193   0.008504
# 6  ...                  True              2000.0 -0.006596   0.009120
# 7  ...                  True              2000.0 -0.006641   0.016804
# 8  ...                  True              2400.0  0.000000   0.000000
# 9  ...                  True              2400.0  0.016270   0.000335
#
#   changeBod quoteVolume24h  volumeUsd24h  priceHigh24h   priceLow24h  \
# 0  0.033959   2.643037e+07  2.643037e+07    283.715000    266.370000
# 1  0.023253   9.316923e+08  9.316923e+08  19767.000000  18464.000000
# 2 -0.000200   1.060431e+05  1.060431e+05      1.000000      0.999700
# 3 -0.002267   6.176442e+06  6.176442e+06      0.061134      0.058499
# 4  0.004867   5.115163e+06  5.115163e+06      6.467000      6.172000
# 5  0.007140   7.908645e+08  7.908645e+08   1355.300000   1254.300000
# 6  0.012767   9.397866e+06  9.397866e+06      0.754269      0.712279
# 7  0.017815   6.994797e+07  6.994797e+07     33.800000     31.640000
# 8  0.000000   7.004018e+07  7.004018e+07      0.999900      0.999800
# 9  0.000893   8.365738e+07  8.365738e+07      0.455775      0.416900
#
#    tokenizedEquity
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
#
# [10 rows x 27 columns]

# %%
df['bid'][0]
# Out:
# 281.81

# %%
label = "BTC/USD",
value = df['bid'][0],
delta = round(df['change24h'][0]*100,2)

# %%
i = df.index[(df['name'] == markets_to_use[1])].tolist()[0]

# %%
print(df['name'][i])
print(df['bid'][i])
print(round(df['change24h'][i]*100,2))
# Out:
# ETH/USD
# 1340.0
# 0.85

# %%
m1, m2, m3, m4, m5 = 1, 2, 3, 4, 5
var_m = [m1, m2, m3, m4, m5]
for j, k in var_m, markets_to_use:
    i = df.index[(df['name'] == k)].tolist()[0]
# Out:
# ETH/USD USDT/USD BNB/USD XRP/USD

# %%
request.individual('BTC/USD')
# Out:
# ask                             19626.0
# baseCurrency                        BTC
# bid                             19625.0
# change1h                       0.003272
# change24h                      0.032732
# changeBod                       0.02781
# enabled                            True
# futureType                         None
# highLeverageFeeExempt              True
# isEtfMarket                       False
# largeOrderThreshold              2400.0
# last                            19625.0
# minProvideSize                   0.0001
# name                            BTC/USD
# postOnly                          False
# price                           19625.0
# priceHigh24h                    19767.0
# priceIncrement                      1.0
# priceLow24h                     18464.0
# quoteCurrency                       USD
# quoteVolume24h           933509926.3197
# restricted                        False
# sizeIncrement                    0.0001
# type                               spot
# underlying                         None
# volumeUsd24h             933509926.3197
# Name: result, dtype: object

# %%
df['bid'][1]
# Out:
# 1350.1

# %%
request.individual('BTC/USD')
# Out:
# ask                            19630.0
# baseCurrency                       BTC
# bid                            19629.0
# change1h                      0.004452
# change24h                     0.033539
# changeBod                     0.028072
# enabled                           True
# futureType                        None
# highLeverageFeeExempt             True
# isEtfMarket                      False
# largeOrderThreshold             2400.0
# last                           19631.0
# minProvideSize                  0.0001
# name                           BTC/USD
# postOnly                         False
# price                          19630.0
# priceHigh24h                   19767.0
# priceIncrement                     1.0
# priceLow24h                    18464.0
# quoteCurrency                      USD
# quoteVolume24h           934040699.348
# restricted                       False
# sizeIncrement                   0.0001
# type                              spot
# underlying                        None
# volumeUsd24h             934040699.348
# Name: result, dtype: object
