# %%
import matplotlib.pyplot as plt  # para gráficas
import seaborn as sns  # para gráficas
import plotly.express as px  # gráficos interactivos
import numpy as np  # análisis de datos
import pandas as pd  # manipulación de datos
import Acquisition.request as request # funciones para conectarse a la api

# %%
df = request.actual_data()
df.head()
# Out:
#          name  enabled  postOnly  priceIncrement  sizeIncrement  \
# 0  1INCH-PERP     True     False          0.0001           1.00
# 1  1INCH-0930     True     False          0.0001           1.00
# 2  1INCH-1230     True     False          0.0001           1.00
# 3   1INCH/USD     True     False          0.0001           1.00
# 4   AAPL-0930     True     False          0.0100           0.01
#
#    minProvideSize      last       bid       ask     price  ...  \
# 0            1.00    0.5893    0.5895    0.5897    0.5895  ...
# 1            1.00    0.5895    0.5852    0.5887    0.5887  ...
# 2            1.00    0.5654    0.5672    0.5714    0.5672  ...
# 3            1.00    0.5901    0.5900    0.5904    0.5901  ...
# 4            0.01  150.0400  149.2700  150.5400  150.0400  ...
#
#   highLeverageFeeExempt largeOrderThreshold  change1h  change24h changeBod  \
# 0                 False               350.0  0.003063   0.003917  0.004601
# 1                 False               350.0  0.002043   0.008393  0.007013
# 2                 False               350.0 -0.004388   0.004783  0.002829
# 3                  True               280.0  0.004084   0.004426  0.004939
# 4                 False               350.0  0.000934  -0.001663  0.000000
#
#   quoteVolume24h  volumeUsd24h  priceHigh24h  priceLow24h  tokenizedEquity
# 0   3.446078e+06  3.446078e+06        0.5932       0.5744              NaN
# 1   8.390383e+03  8.390383e+03        0.5895       0.5720              NaN
# 2   1.414283e+04  1.414283e+04        0.5720       0.5564              NaN
# 3   1.497093e+06  1.497093e+06        0.5937       0.5745              NaN
# 4   8.390311e+04  8.390311e+04      150.7300     145.1300             True
#
# [5 rows x 27 columns]

# %%
df[df.name.str.contains('MATIC')]
# Out:
#                   name  enabled  postOnly  priceIncrement  sizeIncrement  \
# 437         MATIC-PERP     True     False    2.500000e-06       1.000000
# 438         MATIC-1230     True     False    2.500000e-06       1.000000
# 439          MATIC/BTC     True     False    1.000000e-08      10.000000
# 440          MATIC/USD     True     False    1.000000e-06      10.000000
# 859  MATICBEAR2021/USD     True     False    1.000000e-08   10000.000000
# 860      MATICBULL/USD     True     False    1.000000e-07    1000.000000
# 861      MATICHALF/USD     True     False    5.000000e+00       0.000001
# 862     MATICHEDGE/USD     True     False    1.000000e-05       1.000000
#
#      minProvideSize          last           bid           ask         price  \
# 437        1.000000      0.750330      0.750328      0.750330      0.750330
# 438        1.000000      0.734580      0.732230      0.736143      0.734580
# 439       10.000000      0.000038      0.000038      0.000038      0.000038
# 440       10.000000      0.750865      0.750608      0.750788      0.750788
# 859    10000.000000      0.000021      0.000021      0.000022      0.000021
# 860     1000.000000      0.000269      0.000268      0.000270      0.000269
# 861        0.000001  67970.000000  67485.000000  67660.000000  67660.000000
# 862        1.000000      0.115130      0.114140      0.114720      0.114720
#
#      ... highLeverageFeeExempt largeOrderThreshold  change1h  change24h  \
# 437  ...                 False              2500.0  0.003353   0.031956
# 438  ...                 False              2500.0  0.001541   0.034263
# 439  ...                  True              1200.0  0.000521  -0.008267
# 440  ...                  True              2000.0  0.003274   0.032292
# 859  ...                  True               280.0 -0.008829  -0.097716
# 860  ...                  True               280.0  0.013163   0.098695
# 861  ...                  True               280.0  0.001554   0.015763
# 862  ...                  True               280.0 -0.003215  -0.026642
#
#     changeBod quoteVolume24h  volumeUsd24h  priceHigh24h   priceLow24h  \
# 437  0.001318   4.320911e+07  4.320911e+07      0.754663      0.719365
# 438  0.002675   1.222960e+04  1.222960e+04      0.737650      0.705300
# 439 -0.004150   2.912082e+00  5.696988e+04      0.000039      0.000038
# 440  0.001919   8.455766e+06  8.455766e+06      0.754269      0.720000
# 859 -0.014781   3.111836e+04  3.111836e+04      0.000024      0.000021
# 860  0.006726   1.098773e+05  1.098773e+05      0.000272      0.000237
# 861  0.000814   0.000000e+00  0.000000e+00  67970.000000  66300.000000
# 862 -0.001740   5.814262e+02  5.814262e+02      0.118960      0.114170
#
#      tokenizedEquity
# 437              NaN
# 438              NaN
# 439              NaN
# 440              NaN
# 859              NaN
# 860              NaN
# 861              NaN
# 862              NaN
#
# [8 rows x 27 columns]

# %%
markets_to_use = ['BTC/USD', 'ETH/USD', 'USDT/USD', 'BNB/USD', 'XRP/USD', 'SOL/USD', 'DOGE/USD', 'DOT/USD', 'DAI/USD', 'MATIC/USD']

# %%
markets_to_use = ['BTC/USD', 'ETH/USD', 'USDT/USD', 'BNB/USD', 'XRP/USD', 'SOL/USD', 'DOGE/USD', 'DOT/USD', 'DAI/USD', 'MATIC/USD']
df = request.actual_data()
df = df[df.name.isin(markets_to_use)]
df.reset_index(drop=True, inplace=True)
df
# Out:
#         name  enabled  postOnly  priceIncrement  sizeIncrement  \
# 0    BNB/USD     True     False    1.000000e-03         0.0100
# 1    BTC/USD     True     False    1.000000e+00         0.0001
# 2    DAI/USD     True     False    1.000000e-04         0.1000
# 3   DOGE/USD     True     False    5.000000e-07         1.0000
# 4    DOT/USD     True     False    1.000000e-03         0.1000
# 5    ETH/USD     True     False    1.000000e-01         0.0010
# 6  MATIC/USD     True     False    1.000000e-06        10.0000
# 7    SOL/USD     True     False    2.500000e-03         0.0100
# 8   USDT/USD     True     False    1.000000e-04         0.0100
# 9    XRP/USD     True     False    2.500000e-05         1.0000
#
#    minProvideSize          last           bid           ask         price  \
# 0          0.0100    284.852000    284.963000    284.964000    284.963000
# 1          0.0001  19564.000000  19564.000000  19565.000000  19564.000000
# 2          0.1000      0.999900      0.999800      0.999900      0.999900
# 3          1.0000      0.060769      0.060776      0.060776      0.060776
# 4          0.1000      6.465000      6.465000      6.467000      6.465000
# 5          0.0010   1344.200000   1344.100000   1344.200000   1344.200000
# 6         10.0000      0.750865      0.750608      0.750788      0.750788
# 7          0.0100     33.872500     33.872500     33.875000     33.872500
# 8          0.0100      0.999900      0.999800      0.999900      0.999900
# 9          1.0000      0.442750      0.442625      0.442700      0.442700
#
#    ... highLeverageFeeExempt largeOrderThreshold  change1h  change24h  \
# 0  ...                  True              2000.0  0.005207   0.054594
# 1  ...                  True              2400.0  0.004261   0.040749
# 2  ...                  True               280.0  0.000000   0.000100
# 3  ...                  True              2000.0  0.000716   0.024303
# 4  ...                  True              2000.0  0.006069   0.030772
# 5  ...                  True              2400.0  0.003659   0.045663
# 6  ...                  True              2000.0  0.003274   0.032292
# 7  ...                  True              2000.0  0.005716   0.045851
# 8  ...                  True              2400.0  0.000000   0.000000
# 9  ...                  True              2400.0  0.005565   0.037679
#
#   changeBod quoteVolume24h  volumeUsd24h  priceHigh24h   priceLow24h  \
# 0  0.008404   2.271434e+07  2.271434e+07    285.541000    267.662000
# 1  0.006379   8.229055e+08  8.229055e+08  19767.000000  18563.000000
# 2  0.000000   9.661315e+04  9.661315e+04      0.999900      0.999800
# 3  0.001541   5.362813e+06  5.362813e+06      0.061134      0.059033
# 4  0.009525   3.945917e+06  3.945917e+06      6.474000      6.217000
# 5  0.002237   6.609439e+08  6.609439e+08   1355.300000   1254.300000
# 6  0.001919   8.455766e+06  8.455766e+06      0.754269      0.720000
# 7  0.016658   6.485415e+07  6.485415e+07     33.960000     31.842500
# 8  0.000000   6.788316e+07  6.788316e+07      0.999900      0.999800
# 9 -0.018077   7.514911e+07  7.514911e+07      0.455775      0.416900
#
#    tokenizedEquity
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
#
# [10 rows x 27 columns]

# %%
df['bid'][0]
# Out:
# 284.963

# %%
label = "BTC/USD",
value = df['bid'][0],
delta = round(df['change24h'][0]*100,2)

# %%
i = df.index[(df['name'] == markets_to_use[1])].tolist()[0]

# %%
print(df['name'][i])
print(df['bid'][i])
print(round(df['change24h'][i]*100,2))
# Out:
# ETH/USD
# 1344.1
# 4.57

# %%
request.individual('BTC/USD')
# Out:
# ask                             19564.0
# baseCurrency                        BTC
# bid                             19563.0
# change1h                       0.004415
# change24h                       0.04125
# changeBod                      0.006327
# enabled                            True
# futureType                         None
# highLeverageFeeExempt              True
# isEtfMarket                       False
# largeOrderThreshold              2400.0
# last                            19563.0
# minProvideSize                   0.0001
# name                            BTC/USD
# postOnly                          False
# price                           19563.0
# priceHigh24h                    19767.0
# priceIncrement                      1.0
# priceLow24h                     18563.0
# quoteCurrency                       USD
# quoteVolume24h           822905477.8796
# restricted                        False
# sizeIncrement                    0.0001
# type                               spot
# underlying                         None
# volumeUsd24h             822905477.8796
# Name: result, dtype: object

# %%
df['bid'][1]
# Out:
# 19564.0

# %%
request.individual('BTC/USD')
# Out:
# ask                             19564.0
# baseCurrency                        BTC
# bid                             19563.0
# change1h                       0.004415
# change24h                       0.04125
# changeBod                      0.006327
# enabled                            True
# futureType                         None
# highLeverageFeeExempt              True
# isEtfMarket                       False
# largeOrderThreshold              2400.0
# last                            19563.0
# minProvideSize                   0.0001
# name                            BTC/USD
# postOnly                          False
# price                           19563.0
# priceHigh24h                    19767.0
# priceIncrement                      1.0
# priceLow24h                     18563.0
# quoteCurrency                       USD
# quoteVolume24h           822905477.8796
# restricted                        False
# sizeIncrement                    0.0001
# type                               spot
# underlying                         None
# volumeUsd24h             822905477.8796
# Name: result, dtype: object

# %%
request.historical('BTC/USD',2022,9,28,3600)
# Out:
#                               open     high      low    close        volume
# date
# 2022-09-28 05:00:00+00:00  18761.0  18832.0  18652.0  18823.0  2.654427e+07
# 2022-09-28 06:00:00+00:00  18824.0  18883.0  18688.0  18698.0  2.173392e+07
# 2022-09-28 07:00:00+00:00  18700.0  18804.0  18623.0  18784.0  4.563758e+07
# 2022-09-28 08:00:00+00:00  18784.0  18791.0  18696.0  18740.0  1.584411e+07
# 2022-09-28 09:00:00+00:00  18740.0  18742.0  18563.0  18650.0  3.800379e+07
# 2022-09-28 10:00:00+00:00  18650.0  19146.0  18570.0  19007.0  1.156807e+08
# 2022-09-28 11:00:00+00:00  19007.0  19040.0  18850.0  18951.0  4.019089e+07
# 2022-09-28 12:00:00+00:00  18951.0  19124.0  18944.0  19071.0  2.860992e+07
# 2022-09-28 13:00:00+00:00  19071.0  19201.0  19016.0  19125.0  4.914227e+07
# 2022-09-28 14:00:00+00:00  19125.0  19475.0  19043.0  19384.0  8.358748e+07
# 2022-09-28 15:00:00+00:00  19384.0  19499.0  19368.0  19489.0  3.403676e+07
# 2022-09-28 16:00:00+00:00  19489.0  19658.0  19474.0  19510.0  4.799576e+07
# 2022-09-28 17:00:00+00:00  19511.0  19605.0  19266.0  19355.0  3.516775e+07
# 2022-09-28 18:00:00+00:00  19355.0  19633.0  19290.0  19558.0  3.518352e+07
# 2022-09-28 19:00:00+00:00  19557.0  19658.0  19468.0  19551.0  2.836651e+07
# 2022-09-28 20:00:00+00:00  19551.0  19623.0  19496.0  19576.0  1.816995e+07
# 2022-09-28 21:00:00+00:00  19576.0  19769.0  19530.0  19619.0  2.660659e+07
# 2022-09-28 22:00:00+00:00  19619.0  19667.0  19410.0  19487.0  1.806068e+07
# 2022-09-28 23:00:00+00:00  19487.0  19556.0  19389.0  19414.0  1.190721e+07
# 2022-09-29 00:00:00+00:00  19415.0  19523.0  19371.0  19438.0  2.848553e+07
# 2022-09-29 01:00:00+00:00  19438.0  19596.0  19421.0  19492.0  1.360070e+07
# 2022-09-29 02:00:00+00:00  19492.0  19530.0  19280.0  19436.0  3.389751e+07
# 2022-09-29 03:00:00+00:00  19436.0  19535.0  19387.0  19510.0  1.549341e+07
# 2022-09-29 04:00:00+00:00  19510.0  19569.0  19494.0  19563.0  9.301546e+06

# %%
from datetime import datetime
d = datetime(2022, 9, 28)
d = d.date()

# %%
type(d)
# Out:
# datetime.date
