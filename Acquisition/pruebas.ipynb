# %%
import datetime
import requests
import request as request 
import pandas as pd
from datetime import datetime
# from client import FtxClient
# from local_settings import ftxus as settings

# %%
request.historical_datetime('BTC/USD',datetime(2022,1,1),datetime.now())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Sebastián\Documents\Henry\ZIPs Repos Alumnos\PI\PI-03-Dashboard\Acquisition\pruebas.ipynb Celda 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sebasti%C3%A1n/Documents/Henry/ZIPs%20Repos%20Alumnos/PI/PI-03-Dashboard/Acquisition/pruebas.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> request.historical_datetime('BTC/USD',datetime(2022,1,1),datetime.now())
#
# File c:\Users\Sebastián\Documents\Henry\ZIPs Repos Alumnos\PI\PI-03-Dashboard\Acquisition\request.py:44, in historical_datetime(market_name, start_time, end_time, resolution)
#      42 url = api_url + path
#      43 res = requests.get(url).json()
# ---> 44 df = pd.DataFrame(res['result'])
#      45 df['date'] = pd.to_datetime(df['startTime'])
#      46 df = df.set_index('date')
#
# KeyError: 'result'

# %%
api_url = 'https://ftx.com/api'
market_name = 'BTC/USD'
resolution = 15
start_time = datetime.now().timestamp() - 3600
path = f'/markets/{market_name}/candles?resolution={resolution}&start_time={start_time}'
url = api_url + path
res = requests.get(url).json()
df = pd.DataFrame(res['result'])
df['date'] = pd.to_datetime(df['startTime'])
df = df.set_index('date')
df = df.drop(columns = ['startTime', 'time'])

# %%
print(start_time)
print(end_time)
# Out:
# 1641013200.0
# 1664464088.519038

# %%
datetime.now().timestamp()
# Out:
# 1664464439.522341

# %%
datetime.now().timestamp()
# Out:
# 1664464718.615517

# %%
res
# Out:
# {'success': True, 'result': []}

# %%
api_url = 'https://ftx.com/api'
api = "/markets"
url = api_url + api
url
# Out:
# 'https://ftx.com/api/markets'

# %%
markets = requests.get(url).json()
data = markets['result']
data
# Out:
# [{'name': '1INCH-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.5786,
#   'bid': 0.5788,
#   'ask': 0.5789,
#   'price': 0.5788,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': '1INCH',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.005734144222415291,
#   'change24h': -0.008734372324028086,
#   'changeBod': -0.013633265167007498,
#   'quoteVolume24h': 3018832.9216,
#   'volumeUsd24h': 3018832.9216,
#   'priceHigh24h': 0.5932,
#   'priceLow24h': 0.5732},
#  {'name': '1INCH-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.5769,
#   'bid': 0.5759,
#   'ask': 0.5798,
#   'price': 0.5769,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': '1INCH',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.00698202129516495,
#   'change24h': -0.00927357032457496,
#   'changeBod': -0.013171399247348614,
#   'quoteVolume24h': 7546.8527,
#   'volumeUsd24h': 7546.8527,
#   'priceHigh24h': 0.5895,
#   'priceLow24h': 0.5721},
#  {'name': '1INCH-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.5611,
#   'bid': 0.5607,
#   'ask': 0.5619,
#   'price': 0.5611,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': '1INCH',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.005555555555555556,
#   'change24h': -0.007780725022104333,
#   'changeBod': -0.007956152758132957,
#   'quoteVolume24h': 10046.9655,
#   'volumeUsd24h': 10046.9655,
#   'priceHigh24h': 0.572,
#   'priceLow24h': 0.5562},
#  {'name': '1INCH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.5788,
#   'bid': 0.5789,
#   'ask': 0.5794,
#   'price': 0.5789,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': '1INCH',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.005558450581900296,
#   'change24h': -0.008902585173771614,
#   'changeBod': -0.014134877384196186,
#   'quoteVolume24h': 1305408.063,
#   'volumeUsd24h': 1305408.063,
#   'priceHigh24h': 0.5937,
#   'priceLow24h': 0.5733},
#  {'name': 'AAPL-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 143.71,
#   'bid': 143.08,
#   'ask': 143.25,
#   'price': 143.25,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAPL',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0004888950970805978,
#   'change24h': -0.02855011528550115,
#   'changeBod': -0.04525459877366036,
#   'quoteVolume24h': 471446.9494,
#   'volumeUsd24h': 471446.9494,
#   'priceHigh24h': 150.73,
#   'priceLow24h': 142.67},
#  {'name': 'AAPL-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 142.8,
#   'bid': 142.88,
#   'ask': 143.32,
#   'price': 142.88,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAPL',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.0011185682326621924,
#   'change24h': -0.02497611573631773,
#   'changeBod': -0.0442809364548495,
#   'quoteVolume24h': 491455.5541,
#   'volumeUsd24h': 491455.5541,
#   'priceHigh24h': 150.61,
#   'priceLow24h': 141.98},
#  {'name': 'AAPL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 143.29,
#   'bid': 143.1,
#   'ask': 143.29,
#   'price': 143.29,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAPL',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.024043045906552242,
#   'changeBod': -0.042435177759957234,
#   'quoteVolume24h': 230817.4516,
#   'volumeUsd24h': 230817.4516,
#   'priceHigh24h': 150.76,
#   'priceLow24h': 142.64},
#  {'name': 'AAVE-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 75.68,
#   'bid': 75.69,
#   'ask': 75.71,
#   'price': 75.69,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAVE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.011222444889779559,
#   'change24h': -0.008774227344159245,
#   'changeBod': -0.018796992481203006,
#   'quoteVolume24h': 9495225.6253,
#   'volumeUsd24h': 9495225.6253,
#   'priceHigh24h': 77.72,
#   'priceLow24h': 74.31},
#  {'name': 'AAVE-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 76.4,
#   'bid': 75.72,
#   'ask': 76.15,
#   'price': 76.15,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAVE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.01628186307220072,
#   'change24h': -0.000525003281270508,
#   'changeBod': -0.010782021304234866,
#   'quoteVolume24h': 185.8221,
#   'volumeUsd24h': 185.8221,
#   'priceHigh24h': 77.57,
#   'priceLow24h': 74.67},
#  {'name': 'AAVE-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 74.41,
#   'bid': 74.78,
#   'ask': 75.58,
#   'price': 74.78,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAVE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.004972449939524257,
#   'change24h': -0.01669953977646285,
#   'changeBod': -0.024523871641012263,
#   'quoteVolume24h': 750.6713,
#   'volumeUsd24h': 750.6713,
#   'priceHigh24h': 76.98,
#   'priceLow24h': 74.18},
#  {'name': 'AAVE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 75.91,
#   'bid': 75.67,
#   'ask': 75.73,
#   'price': 75.73,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': 0.011621693828479829,
#   'change24h': -0.007340411587364005,
#   'changeBod': -0.018405703175631886,
#   'quoteVolume24h': 825374.4056,
#   'volumeUsd24h': 825374.4056,
#   'priceHigh24h': 77.73,
#   'priceLow24h': 74.24},
#  {'name': 'AAVE/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 76.03,
#   'bid': 75.62,
#   'ask': 75.76,
#   'price': 75.76,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': 0.010537548352674403,
#   'change24h': -0.007597589730154571,
#   'changeBod': -0.01827134896980692,
#   'quoteVolume24h': 132467.5692,
#   'volumeUsd24h': 132467.5692,
#   'priceHigh24h': 77.75,
#   'priceLow24h': 74.32},
#  {'name': 'ABNB-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.025,
#   'minProvideSize': 0.025,
#   'last': 110.03,
#   'bid': 107.305,
#   'ask': 107.57,
#   'price': 107.57,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ABNB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0006977068700869807,
#   'change24h': -0.01302871823103037,
#   'changeBod': -0.025325057762877724,
#   'quoteVolume24h': 35.75975,
#   'volumeUsd24h': 35.75975,
#   'priceHigh24h': 111.26,
#   'priceLow24h': 106.865},
#  {'name': 'ABNB-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.025,
#   'minProvideSize': 0.025,
#   'last': 108.2,
#   'bid': 107.345,
#   'ask': 107.54,
#   'price': 107.54,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ABNB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0007910288027546414,
#   'change24h': -0.013394495412844036,
#   'changeBod': -0.026434908564186132,
#   'quoteVolume24h': 324.6,
#   'volumeUsd24h': 324.6,
#   'priceHigh24h': 111.325,
#   'priceLow24h': 106.895},
#  {'name': 'ABNB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.025,
#   'minProvideSize': 0.025,
#   'last': 106.975,
#   'bid': 107.215,
#   'ask': 107.695,
#   'price': 107.215,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ABNB',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.000886855862584018,
#   'change24h': -0.013978939623856164,
#   'changeBod': -0.029421083601140634,
#   'quoteVolume24h': 3396.377875,
#   'volumeUsd24h': 3396.377875,
#   'priceHigh24h': 111.2,
#   'priceLow24h': 106.23},
#  {'name': 'ACB-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.302,
#   'bid': 1.266,
#   'ask': 1.273,
#   'price': 1.273,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ACB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.01596169193934557,
#   'change24h': 0.013535031847133758,
#   'changeBod': -0.02227342549923195,
#   'quoteVolume24h': 279.7128,
#   'volumeUsd24h': 279.7128,
#   'priceHigh24h': 1.307,
#   'priceLow24h': 1.233},
#  {'name': 'ACB-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.29,
#   'bid': 1.267,
#   'ask': 1.274,
#   'price': 1.274,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ACB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.01594896331738437,
#   'change24h': 0.01675977653631285,
#   'changeBod': -0.012403100775193798,
#   'quoteVolume24h': 2884.7844,
#   'volumeUsd24h': 2884.7844,
#   'priceHigh24h': 1.308,
#   'priceLow24h': 1.234},
#  {'name': 'ACB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.243,
#   'bid': 1.266,
#   'ask': 1.272,
#   'price': 1.266,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ACB',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.014423076923076924,
#   'change24h': 0.005559968228752979,
#   'changeBod': -0.029885057471264367,
#   'quoteVolume24h': 458.9182,
#   'volumeUsd24h': 458.9182,
#   'priceHigh24h': 1.309,
#   'priceLow24h': 1.234},
#  {'name': 'ADA-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.4322,
#   'bid': 0.4322,
#   'ask': 0.432205,
#   'price': 0.4322,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ADA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.006802087215803205,
#   'change24h': -0.006059769797739372,
#   'changeBod': -0.011775465874013947,
#   'quoteVolume24h': 38373589.246425,
#   'volumeUsd24h': 38373589.246425,
#   'priceHigh24h': 0.440575,
#   'priceLow24h': 0.42748},
#  {'name': 'ADA-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.43219,
#   'bid': 0.431505,
#   'ask': 0.43188,
#   'price': 0.43188,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ADA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.006232453023613425,
#   'change24h': -0.004953574637697855,
#   'changeBod': -0.009722094836283592,
#   'quoteVolume24h': 701488.314895,
#   'volumeUsd24h': 701488.314895,
#   'priceHigh24h': 0.43932,
#   'priceLow24h': 0.427525},
#  {'name': 'ADA-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.422505,
#   'bid': 0.42237,
#   'ask': 0.424535,
#   'price': 0.422505,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ADA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.006827280526165285,
#   'change24h': -0.007108781989518953,
#   'changeBod': -0.010839664274760907,
#   'quoteVolume24h': 25501.263995,
#   'volumeUsd24h': 25501.263995,
#   'priceHigh24h': 0.431535,
#   'priceLow24h': 0.418005},
#  {'name': 'AGLD-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.3165,
#   'bid': 0.3165,
#   'ask': 0.317,
#   'price': 0.3165,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AGLD',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.009569377990430622,
#   'change24h': -0.0015772870662460567,
#   'changeBod': -0.0015772870662460567,
#   'quoteVolume24h': 3560904.0284,
#   'volumeUsd24h': 3560904.0284,
#   'priceHigh24h': 0.3255,
#   'priceLow24h': 0.3115},
#  {'name': 'AGLD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.3165,
#   'bid': 0.315,
#   'ask': 0.3175,
#   'price': 0.3165,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AGLD',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.009569377990430622,
#   'change24h': -0.006279434850863423,
#   'changeBod': -0.0015772870662460567,
#   'quoteVolume24h': 277881.7906,
#   'volumeUsd24h': 277881.7906,
#   'priceHigh24h': 0.3245,
#   'priceLow24h': 0.3115},
#  {'name': 'AKRO/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.00377,
#   'bid': 0.003755,
#   'ask': 0.003775,
#   'price': 0.00377,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AKRO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.005333333333333333,
#   'change24h': -0.04314720812182741,
#   'changeBod': -0.04677623261694058,
#   'quoteVolume24h': 5033.48963,
#   'volumeUsd24h': 5033.48963,
#   'priceHigh24h': 0.004105,
#   'priceLow24h': 0.003655},
#  {'name': 'AKRO/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.003775,
#   'bid': 0.00376,
#   'ask': 0.00378,
#   'price': 0.003775,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AKRO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.005326231691078562,
#   'change24h': -0.04066073697585769,
#   'changeBod': -0.045512010113780026,
#   'quoteVolume24h': 5362.41986,
#   'volumeUsd24h': 5362.41986,
#   'priceHigh24h': 0.0041,
#   'priceLow24h': 0.00365},
#  {'name': 'ALCX-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 21.0,
#   'bid': 21.0,
#   'ask': 21.1,
#   'price': 21.0,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALCX',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.029411764705882353,
#   'change24h': 0.05,
#   'changeBod': 0.019417475728155338,
#   'quoteVolume24h': 562920.7233,
#   'volumeUsd24h': 562920.7233,
#   'priceHigh24h': 22.2,
#   'priceLow24h': 20.0},
#  {'name': 'ALCX/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 21.2,
#   'bid': 21.1,
#   'ask': 21.2,
#   'price': 21.2,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALCX',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.02912621359223301,
#   'change24h': 0.06,
#   'changeBod': 0.02912621359223301,
#   'quoteVolume24h': 22571.1638,
#   'volumeUsd24h': 22571.1638,
#   'priceHigh24h': 22.2,
#   'priceLow24h': 19.9},
#  {'name': 'ALEPH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.1181,
#   'bid': 0.1177,
#   'ask': 0.1194,
#   'price': 0.1181,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALEPH',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.001271725307333616,
#   'change24h': 0.0068201193520886615,
#   'changeBod': -0.009228187919463088,
#   'quoteVolume24h': 49138.2041,
#   'volumeUsd24h': 49138.2041,
#   'priceHigh24h': 0.1209,
#   'priceLow24h': 0.11685},
#  {'name': 'ALGO-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3407,
#   'bid': 0.3409,
#   'ask': 0.341,
#   'price': 0.3409,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALGO',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.008579881656804733,
#   'change24h': -0.013028372900984365,
#   'changeBod': -0.028221208665906498,
#   'quoteVolume24h': 25902870.4859,
#   'volumeUsd24h': 25902870.4859,
#   'priceHigh24h': 0.3642,
#   'priceLow24h': 0.3334},
#  {'name': 'ALGO-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.34,
#   'bid': 0.3406,
#   'ask': 0.3425,
#   'price': 0.3406,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALGO',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.005609684086211987,
#   'change24h': -0.01246738184981154,
#   'changeBod': -0.027135104255926877,
#   'quoteVolume24h': 1291.4635,
#   'volumeUsd24h': 1291.4635,
#   'priceHigh24h': 0.3637,
#   'priceLow24h': 0.3343},
#  {'name': 'ALGO-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3425,
#   'bid': 0.3414,
#   'ask': 0.3427,
#   'price': 0.3425,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALGO',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.013313609467455622,
#   'change24h': -0.011544011544011544,
#   'changeBod': -0.025881683731513082,
#   'quoteVolume24h': 35409.9644,
#   'volumeUsd24h': 35409.9644,
#   'priceHigh24h': 0.3642,
#   'priceLow24h': 0.3351},
#  {'name': 'ALGO/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.342,
#   'bid': 0.3407,
#   'ask': 0.341,
#   'price': 0.341,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': 0.0076832151300236405,
#   'change24h': -0.011880614314691394,
#   'changeBod': -0.027381631488876214,
#   'quoteVolume24h': 560213.6981,
#   'volumeUsd24h': 560213.6981,
#   'priceHigh24h': 0.364,
#   'priceLow24h': 0.3333},
#  {'name': 'ALGO/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.342,
#   'bid': 0.3406,
#   'ask': 0.3411,
#   'price': 0.3411,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': 0.010966212211025488,
#   'change24h': -0.012735166425470333,
#   'changeBod': -0.027096406160867084,
#   'quoteVolume24h': 45679.6506,
#   'volumeUsd24h': 45679.6506,
#   'priceHigh24h': 0.3637,
#   'priceLow24h': 0.333},
#  {'name': 'ALICE-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.6825,
#   'bid': 1.68,
#   'ask': 1.6825,
#   'price': 1.6825,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALICE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0074850299401197605,
#   'change24h': 0.01355421686746988,
#   'changeBod': -0.011747430249632892,
#   'quoteVolume24h': 1341883.96225,
#   'volumeUsd24h': 1341883.96225,
#   'priceHigh24h': 1.7225,
#   'priceLow24h': 1.6525},
#  {'name': 'ALICE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.685,
#   'bid': 1.6775,
#   'ask': 1.685,
#   'price': 1.685,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALICE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.007473841554559043,
#   'change24h': 0.012012012012012012,
#   'changeBod': -0.013177159590043924,
#   'quoteVolume24h': 5868.1475,
#   'volumeUsd24h': 5868.1475,
#   'priceHigh24h': 1.7225,
#   'priceLow24h': 1.655},
#  {'name': 'ALPHA-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.1091,
#   'bid': 0.109,
#   'ask': 0.10905,
#   'price': 0.10905,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALPHA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.011595547309833023,
#   'change24h': 0.0292590844738084,
#   'changeBod': -0.02197309417040359,
#   'quoteVolume24h': 1666669.9337,
#   'volumeUsd24h': 1666669.9337,
#   'priceHigh24h': 0.1134,
#   'priceLow24h': 0.1055},
#  {'name': 'ALPHA/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.1093,
#   'bid': 0.10895,
#   'ask': 0.1092,
#   'price': 0.1092,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALPHA',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.01345707656612529,
#   'change24h': 0.03067484662576687,
#   'changeBod': -0.019308486753480018,
#   'quoteVolume24h': 284267.4077,
#   'volumeUsd24h': 284267.4077,
#   'priceHigh24h': 0.1133,
#   'priceLow24h': 0.10555},
#  {'name': 'ALT-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.05,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1847.2,
#   'bid': 1847.6,
#   'ask': 1848.7,
#   'price': 1847.6,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALT',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 600.0,
#   'change1h': 0.01110928692606578,
#   'change24h': 0.004048582995951417,
#   'changeBod': -0.009807599549815103,
#   'quoteVolume24h': 3239650.43265,
#   'volumeUsd24h': 3239650.43265,
#   'priceHigh24h': 1873.95,
#   'priceLow24h': 1819.05},
#  {'name': 'ALT-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.05,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1850.15,
#   'bid': 1840.6,
#   'ask': 1850.6,
#   'price': 1850.15,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALT',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 600.0,
#   'change1h': 0.014753873577402989,
#   'change24h': 0.006281953660393778,
#   'changeBod': -0.007856070356070355,
#   'quoteVolume24h': 68496.2077,
#   'volumeUsd24h': 68496.2077,
#   'priceHigh24h': 1870.55,
#   'priceLow24h': 1819.15},
#  {'name': 'ALT-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.05,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1818.05,
#   'bid': 1812.3,
#   'ask': 1818.2,
#   'price': 1818.05,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALT',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 600.0,
#   'change1h': 0.014933288673030759,
#   'change24h': 0.006950983107172529,
#   'changeBod': -0.007533367906760925,
#   'quoteVolume24h': 41773.5779,
#   'volumeUsd24h': 41773.5779,
#   'priceHigh24h': 1844.65,
#   'priceLow24h': 1785.8},
#  {'name': 'AMC-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 13.41,
#   'bid': 13.1425,
#   'ask': 13.4975,
#   'price': 13.41,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMC',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0,
#   'change24h': -0.0016750418760469012,
#   'changeBod': -0.010514665190924184,
#   'quoteVolume24h': 908.8885,
#   'volumeUsd24h': 908.8885,
#   'priceHigh24h': 13.955,
#   'priceLow24h': 13.3375},
#  {'name': 'AMC-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 7.66,
#   'bid': 7.2375,
#   'ask': 7.2875,
#   'price': 7.2875,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMC',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0069084628670120895,
#   'change24h': -0.03316749585406302,
#   'changeBod': -0.04488859764089122,
#   'quoteVolume24h': 1676.7,
#   'volumeUsd24h': 1676.7,
#   'priceHigh24h': 7.7175,
#   'priceLow24h': 7.185},
#  {'name': 'AMC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 7.28,
#   'bid': 7.24,
#   'ask': 7.3025,
#   'price': 7.28,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMC',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0051777701070072485,
#   'change24h': -0.0395778364116095,
#   'changeBod': -0.04336399474375821,
#   'quoteVolume24h': 5204.624,
#   'volumeUsd24h': 5204.624,
#   'priceHigh24h': 7.7725,
#   'priceLow24h': 7.19},
#  {'name': 'AMD-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 64.76,
#   'bid': 64.32,
#   'ask': 64.55,
#   'price': 64.55,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMD',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.0006192909119058678,
#   'change24h': -0.05670027765599883,
#   'changeBod': -0.05435101084090243,
#   'quoteVolume24h': 10628.792,
#   'volumeUsd24h': 10628.792,
#   'priceHigh24h': 68.88,
#   'priceLow24h': 64.3},
#  {'name': 'AMD-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 64.86,
#   'bid': 64.47,
#   'ask': 64.58,
#   'price': 64.58,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMD',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.00324124093224263,
#   'change24h': -0.05252347417840376,
#   'changeBod': -0.0521062674299134,
#   'quoteVolume24h': 30754.4722,
#   'volumeUsd24h': 30754.4722,
#   'priceHigh24h': 68.91,
#   'priceLow24h': 64.33},
#  {'name': 'AMD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 64.3,
#   'bid': 64.42,
#   'ask': 64.55,
#   'price': 64.42,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMD',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0034034653465346535,
#   'change24h': -0.054870892018779344,
#   'changeBod': -0.05556370033719396,
#   'quoteVolume24h': 2069.609,
#   'volumeUsd24h': 2069.609,
#   'priceHigh24h': 68.84,
#   'priceLow24h': 64.24},
#  {'name': 'AMPL-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 1.1313,
#   'bid': 1.1312,
#   'ask': 1.1313,
#   'price': 1.1313,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMPL',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0022147413182140325,
#   'change24h': 0.003014451635783314,
#   'changeBod': -0.012223871474722781,
#   'quoteVolume24h': 73392.575,
#   'volumeUsd24h': 73392.575,
#   'priceHigh24h': 1.1558,
#   'priceLow24h': 1.1093},
#  {'name': 'AMPL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 1.1397,
#   'bid': 1.1397,
#   'ask': 1.1461,
#   'price': 1.1397,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMPL',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.005735968937522061,
#   'change24h': 0.003345364908882824,
#   'changeBod': -0.008784136371542878,
#   'quoteVolume24h': 27918.8637,
#   'volumeUsd24h': 27918.8637,
#   'priceHigh24h': 1.18,
#   'priceLow24h': 1.1088},
#  {'name': 'AMPL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 1.1402,
#   'bid': 1.1394,
#   'ask': 1.1454,
#   'price': 1.1402,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMPL',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.010099220411055989,
#   'change24h': -0.009124880507517164,
#   'changeBod': -0.009727288518325517,
#   'quoteVolume24h': 31351.844,
#   'volumeUsd24h': 31351.844,
#   'priceHigh24h': 1.1669,
#   'priceLow24h': 1.1133},
#  {'name': 'AMZN-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 113.9,
#   'bid': 113.5,
#   'ask': 114.0,
#   'price': 113.9,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMZN',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.006183745583038869,
#   'change24h': -0.01725625539257981,
#   'changeBod': -0.027327070879590094,
#   'quoteVolume24h': 2046.7,
#   'volumeUsd24h': 2046.7,
#   'priceHigh24h': 118.2,
#   'priceLow24h': 113.2},
#  {'name': 'AMZN-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 113.6,
#   'bid': 113.5,
#   'ask': 113.9,
#   'price': 113.6,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMZN',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0035335689045936395,
#   'change24h': -0.018150388936905792,
#   'changeBod': -0.026563838903170524,
#   'quoteVolume24h': 42001.0985,
#   'volumeUsd24h': 42001.0985,
#   'priceHigh24h': 118.2,
#   'priceLow24h': 112.7},
#  {'name': 'AMZN/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 113.8,
#   'bid': 113.7,
#   'ask': 113.9,
#   'price': 113.8,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMZN',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0026431718061674008,
#   'change24h': -0.019810508182601206,
#   'changeBod': -0.03148936170212766,
#   'quoteVolume24h': 42814.1071,
#   'volumeUsd24h': 42814.1071,
#   'priceHigh24h': 118.2,
#   'priceLow24h': 113.3},
#  {'name': 'APE-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.3685,
#   'bid': 5.3695,
#   'ask': 5.37,
#   'price': 5.3695,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'APE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.011776898436027888,
#   'change24h': 0.0018658456945610598,
#   'changeBod': -0.0036184820931527183,
#   'quoteVolume24h': 18850482.14205,
#   'volumeUsd24h': 18850482.14205,
#   'priceHigh24h': 5.454,
#   'priceLow24h': 5.2755},
#  {'name': 'APE-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.3,
#   'bid': 5.356,
#   'ask': 5.3745,
#   'price': 5.356,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'APE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.010566037735849057,
#   'change24h': 0.00205799812909261,
#   'changeBod': -0.006215789961963076,
#   'quoteVolume24h': 2483.9157,
#   'volumeUsd24h': 2483.9157,
#   'priceHigh24h': 5.4415,
#   'priceLow24h': 5.2825},
#  {'name': 'APE-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.2485,
#   'bid': 5.2315,
#   'ask': 5.2665,
#   'price': 5.2485,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'APE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.011369110704306773,
#   'change24h': 0.0,
#   'changeBod': -0.0030392249976256055,
#   'quoteVolume24h': 1716.0452,
#   'volumeUsd24h': 1716.0452,
#   'priceHigh24h': 5.317,
#   'priceLow24h': 5.1665},
#  {'name': 'APE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.3675,
#   'bid': 5.368,
#   'ask': 5.372,
#   'price': 5.368,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'APE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.01225721289835942,
#   'change24h': 0.0013057265435553068,
#   'changeBod': -0.0038968268695490815,
#   'quoteVolume24h': 2553546.6948,
#   'volumeUsd24h': 2553546.6948,
#   'priceHigh24h': 5.453,
#   'priceLow24h': 5.2765},
#  {'name': 'APEAMC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 3.3225,
#   'bid': 3.075,
#   'ask': 3.0875,
#   'price': 3.0875,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'APEAMC',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.009623095429029671,
#   'change24h': -0.07766990291262135,
#   'changeBod': -0.07698056801195814,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 3.4675,
#   'priceLow24h': 3.0825},
#  {'name': 'APHA/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 2.515,
#   'bid': 2.396,
#   'ask': 2.4,
#   'price': 2.4,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'APHA',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.010526315789473684,
#   'change24h': -0.015586546349466776,
#   'changeBod': -0.047619047619047616,
#   'quoteVolume24h': 182.589,
#   'volumeUsd24h': 182.589,
#   'priceHigh24h': 2.538,
#   'priceLow24h': 2.367},
#  {'name': 'AR-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 9.028,
#   'bid': 9.024,
#   'ask': 9.035,
#   'price': 9.028,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AR',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0018865830651426034,
#   'change24h': -0.021991116888744448,
#   'changeBod': -0.032472403815239526,
#   'quoteVolume24h': 1601589.4106,
#   'volumeUsd24h': 1601589.4106,
#   'priceHigh24h': 9.446,
#   'priceLow24h': 8.936},
#  {'name': 'ARKK-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 38.33,
#   'bid': 37.95,
#   'ask': 38.04,
#   'price': 38.04,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ARKK',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.005285412262156448,
#   'change24h': -0.03671815649531527,
#   'changeBod': -0.04852426213106553,
#   'quoteVolume24h': 5970.7932,
#   'volumeUsd24h': 5970.7932,
#   'priceHigh24h': 40.36,
#   'priceLow24h': 37.61},
#  {'name': 'ARKK-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 37.98,
#   'bid': 37.98,
#   'ask': 38.08,
#   'price': 37.98,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ARKK',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.001318217769575534,
#   'change24h': -0.03750633552965028,
#   'changeBod': -0.047642928786359076,
#   'quoteVolume24h': 50015.6505,
#   'volumeUsd24h': 50015.6505,
#   'priceHigh24h': 40.39,
#   'priceLow24h': 37.62},
#  {'name': 'ARKK/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 37.97,
#   'bid': 37.85,
#   'ask': 38.04,
#   'price': 37.97,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ARKK',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.005029115934356803,
#   'change24h': -0.03556007112014224,
#   'changeBod': -0.052408285500374345,
#   'quoteVolume24h': 92599.4432,
#   'volumeUsd24h': 92599.4432,
#   'priceHigh24h': 40.35,
#   'priceLow24h': 37.62},
#  {'name': 'ASD-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.10595,
#   'bid': 0.1057,
#   'ask': 0.10595,
#   'price': 0.10595,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ASD',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.00018880392712168414,
#   'change24h': -0.017070229149271733,
#   'changeBod': -0.037693006357856496,
#   'quoteVolume24h': 198536.191194,
#   'volumeUsd24h': 198536.191194,
#   'priceHigh24h': 0.111,
#   'priceLow24h': 0.10502},
#  {'name': 'ASD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.10583,
#   'bid': 0.10585,
#   'ask': 0.10609,
#   'price': 0.10585,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ASD',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.001132395961121072,
#   'change24h': -0.014798957557706627,
#   'changeBod': -0.034831768031366825,
#   'quoteVolume24h': 42107.663118,
#   'volumeUsd24h': 42107.663118,
#   'priceHigh24h': 0.11122,
#   'priceLow24h': 0.1052},
#  {'name': 'ATLAS-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.0044345,
#   'bid': 0.0044195,
#   'ask': 0.00443475,
#   'price': 0.0044345,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATLAS',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.01250071351104515,
#   'change24h': -0.006274509803921568,
#   'changeBod': -0.011039250669045495,
#   'quoteVolume24h': 234934.9111125,
#   'volumeUsd24h': 234934.9111125,
#   'priceHigh24h': 0.0045725,
#   'priceLow24h': 0.00436},
#  {'name': 'ATLAS/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.004425,
#   'bid': 0.004425,
#   'ask': 0.00443825,
#   'price': 0.004425,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ATLAS',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.007743110908676839,
#   'change24h': -0.009069533087000335,
#   'changeBod': -0.014257072844731567,
#   'quoteVolume24h': 164366.470155,
#   'volumeUsd24h': 164366.470155,
#   'priceHigh24h': 0.00457775,
#   'priceLow24h': 0.00437475},
#  {'name': 'ATOM-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 12.68,
#   'bid': 12.679,
#   'ask': 12.68,
#   'price': 12.68,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATOM',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.009554140127388535,
#   'change24h': -0.024502827249297997,
#   'changeBod': -0.0203955500618047,
#   'quoteVolume24h': 115034454.02989,
#   'volumeUsd24h': 115034454.02989,
#   'priceHigh24h': 13.32,
#   'priceLow24h': 12.4115},
#  {'name': 'ATOM-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 12.698,
#   'bid': 12.665,
#   'ask': 12.7325,
#   'price': 12.698,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATOM',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.0053044097854485,
#   'change24h': -0.024131570857669843,
#   'changeBod': -0.01824648214009587,
#   'quoteVolume24h': 9597.225415,
#   'volumeUsd24h': 9597.225415,
#   'priceHigh24h': 13.2595,
#   'priceLow24h': 12.467},
#  {'name': 'ATOM-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 12.2765,
#   'bid': 12.279,
#   'ask': 12.36,
#   'price': 12.279,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATOM',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.007301066447908121,
#   'change24h': -0.03185366238271702,
#   'changeBod': -0.022994907702100574,
#   'quoteVolume24h': 222747.510855,
#   'volumeUsd24h': 222747.510855,
#   'priceHigh24h': 12.9,
#   'priceLow24h': 12.0595},
#  {'name': 'ATOM/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 12.68,
#   'bid': 12.685,
#   'ask': 12.6925,
#   'price': 12.685,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ATOM',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.007545671167593328,
#   'change24h': -0.024793388429752067,
#   'changeBod': -0.0217852323115481,
#   'quoteVolume24h': 7767693.44225,
#   'volumeUsd24h': 7767693.44225,
#   'priceHigh24h': 13.305,
#   'priceLow24h': 12.425},
#  {'name': 'ATOM/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 12.6725,
#   'bid': 12.675,
#   'ask': 12.695,
#   'price': 12.675,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ATOM',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': 0.006751389992057188,
#   'change24h': -0.026871401151631478,
#   'changeBod': -0.022179363548698167,
#   'quoteVolume24h': 610552.7505,
#   'volumeUsd24h': 610552.7505,
#   'priceHigh24h': 13.32,
#   'priceLow24h': 12.425},
#  {'name': 'AUDIO-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.21,
#   'bid': 0.21,
#   'ask': 0.2105,
#   'price': 0.21,
# ...
#   'quoteVolume24h': 245.06,
#   'volumeUsd24h': 245.06,
#   'priceHigh24h': 1.73e-06,
#   'priceLow24h': 1.57e-06},
#  {'name': 'VETBEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 100000.0,
#   'minProvideSize': 100000.0,
#   'last': 1.61e-06,
#   'bid': 1.58e-06,
#   'ask': 1.6e-06,
#   'price': 1.6e-06,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -0.030303030303030304,
#   'change24h': -0.041916167664670656,
#   'changeBod': -0.012345679012345678,
#   'quoteVolume24h': 29.143,
#   'volumeUsd24h': 29.143,
#   'priceHigh24h': 1.68e-06,
#   'priceLow24h': 1.57e-06},
#  {'name': 'VETBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 8.816e-05,
#   'bid': 8.849e-05,
#   'ask': 8.944e-05,
#   'price': 8.849e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.03063126019100862,
#   'change24h': 0.05621866793984245,
#   'changeBod': 0.005225491309780756,
#   'quoteVolume24h': 2686.60023,
#   'volumeUsd24h': 2686.60023,
#   'priceHigh24h': 9.031e-05,
#   'priceLow24h': 8.339e-05},
#  {'name': 'VETBULL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 8.88e-05,
#   'bid': 8.841e-05,
#   'ask': 8.964e-05,
#   'price': 8.88e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.02080698930911599,
#   'change24h': 0.05714285714285714,
#   'changeBod': 0.0004506534474988734,
#   'quoteVolume24h': 87.79829,
#   'volumeUsd24h': 87.79829,
#   'priceHigh24h': 9.009e-05,
#   'priceLow24h': 8.356e-05},
#  {'name': 'VETHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 100.5,
#   'bid': 98.0,
#   'ask': 99.0,
#   'price': 99.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.01,
#   'change24h': -0.014925373134328358,
#   'changeBod': -0.005025125628140704,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 100.5,
#   'priceLow24h': 98.5},
#  {'name': 'XAUTBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 5660.0,
#   'bid': 5485.0,
#   'ask': 5660.0,
#   'price': 5660.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.008756567425569177,
#   'changeBod': -0.00088261253309797,
#   'quoteVolume24h': 1094.6518,
#   'volumeUsd24h': 1094.6518,
#   'priceHigh24h': 5710.0,
#   'priceLow24h': 5597.5},
#  {'name': 'XAUTBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 4425.0,
#   'bid': 4674.0,
#   'ask': 4760.0,
#   'price': 4674.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.01963350785340314,
#   'change24h': 0.010376134889753566,
#   'changeBod': -0.003198976327575176,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 4720.0,
#   'priceLow24h': 4425.0},
#  {'name': 'XAUTHALF/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.25,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 5657.25,
#   'bid': 5645.25,
#   'ask': 5668.25,
#   'price': 5657.25,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTHALF',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0012831858407079647,
#   'change24h': 0.0,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 5657.25,
#   'priceLow24h': 5646.75},
#  {'name': 'XAUTHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 4926.5,
#   'bid': 4884.5,
#   'ask': 4921.0,
#   'price': 4921.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0011164112453059983,
#   'change24h': -0.0011164112453059983,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 4926.5,
#   'priceLow24h': 4908.0},
#  {'name': 'XLMBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.0106225,
#   'bid': 0.0104325,
#   'ask': 0.0106025,
#   'price': 0.0106025,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XLMBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.01073011429904362,
#   'change24h': 0.025386847195357835,
#   'changeBod': 0.026131139608032906,
#   'quoteVolume24h': 87.344425,
#   'volumeUsd24h': 87.344425,
#   'priceHigh24h': 0.010865,
#   'priceLow24h': 0.010015},
#  {'name': 'XLMBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-07,
#   'sizeIncrement': 100.0,
#   'minProvideSize': 100.0,
#   'last': 0.001916,
#   'bid': 0.0019845,
#   'ask': 0.0020175,
#   'price': 0.0019845,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XLMBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.026642524573202275,
#   'change24h': -0.039448209099709586,
#   'changeBod': -0.03053248656570591,
#   'quoteVolume24h': 4199.04035,
#   'volumeUsd24h': 4199.04035,
#   'priceHigh24h': 0.0021065,
#   'priceLow24h': 0.001916},
#  {'name': 'XRPBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000000.0,
#   'minProvideSize': 10000000.0,
#   'last': 5e-08,
#   'bid': 5e-08,
#   'ask': 7e-08,
#   'price': 5e-08,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 5e-08,
#   'priceLow24h': 5e-08},
#  {'name': 'XRPBEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000000.0,
#   'minProvideSize': 10000000.0,
#   'last': 9e-08,
#   'bid': 5e-08,
#   'ask': 1.7e-07,
#   'price': 9e-08,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 9e-08,
#   'priceLow24h': 9e-08},
#  {'name': 'XRPBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 2.751e-05,
#   'bid': 2.751e-05,
#   'ask': 2.768e-05,
#   'price': 2.751e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.019644180874722018,
#   'change24h': -0.0202991452991453,
#   'changeBod': -0.11571841851494696,
#   'quoteVolume24h': 95687.40718,
#   'volumeUsd24h': 95687.40718,
#   'priceHigh24h': 3.264e-05,
#   'priceLow24h': 2.649e-05},
#  {'name': 'XRPBULL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 2.788e-05,
#   'bid': 2.741e-05,
#   'ask': 2.775e-05,
#   'price': 2.775e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.03699551569506727,
#   'change24h': -0.0106951871657754,
#   'changeBod': -0.1193271977150111,
#   'quoteVolume24h': 3141.47006,
#   'volumeUsd24h': 3141.47006,
#   'priceHigh24h': 3.209e-05,
#   'priceLow24h': 2.637e-05},
#  {'name': 'XRPHALF/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 12815.5,
#   'bid': 12592.5,
#   'ask': 12624.5,
#   'price': 12624.5,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPHALF',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.004056149838946992,
#   'change24h': -0.0011867558052138139,
#   'changeBod': -0.01983695652173913,
#   'quoteVolume24h': 15.12229,
#   'volumeUsd24h': 15.12229,
#   'priceHigh24h': 12987.5,
#   'priceLow24h': 12547.5},
#  {'name': 'XRPHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 47.44,
#   'bid': 46.92,
#   'ask': 47.105,
#   'price': 47.105,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.007061551433389545,
#   'change24h': 0.0057649193978861965,
#   'changeBod': 0.04007507175977037,
#   'quoteVolume24h': 782.71621,
#   'volumeUsd24h': 782.71621,
#   'priceHigh24h': 47.455,
#   'priceLow24h': 44.825},
#  {'name': 'XTZBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000000.0,
#   'minProvideSize': 1000000.0,
#   'last': 1.4e-07,
#   'bid': 1.4e-07,
#   'ask': 1.6e-07,
#   'price': 1.4e-07,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.06666666666666667,
#   'changeBod': -0.06666666666666667,
#   'quoteVolume24h': 11.08,
#   'volumeUsd24h': 11.08,
#   'priceHigh24h': 1.5e-07,
#   'priceLow24h': 1.4e-07},
#  {'name': 'XTZBEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000000.0,
#   'minProvideSize': 1000000.0,
#   'last': 1.3e-07,
#   'bid': 1.4e-07,
#   'ask': 1.6e-07,
#   'price': 1.4e-07,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 1.5e-07,
#   'priceLow24h': 1.3e-07},
#  {'name': 'XTZBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 1.826e-05,
#   'bid': 1.765e-05,
#   'ask': 1.861e-05,
#   'price': 1.826e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.000547945205479452,
#   'change24h': -0.03232644409114997,
#   'changeBod': -0.061182519280205655,
#   'quoteVolume24h': 207.8515,
#   'volumeUsd24h': 207.8515,
#   'priceHigh24h': 1.977e-05,
#   'priceLow24h': 1.752e-05},
#  {'name': 'XTZBULL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 1.919e-05,
#   'bid': 1.703e-05,
#   'ask': 1.864e-05,
#   'price': 1.864e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.021369863013698632,
#   'change24h': 0.009204114780725501,
#   'changeBod': -0.0286607608129234,
#   'quoteVolume24h': 0.1919,
#   'volumeUsd24h': 0.1919,
#   'priceHigh24h': 1.919e-05,
#   'priceLow24h': 1.808e-05},
#  {'name': 'XTZHALF/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.25,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 6423.0,
#   'bid': 6133.5,
#   'ask': 6180.75,
#   'price': 6180.75,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZHALF',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0030021501886486265,
#   'change24h': -0.001816860465116279,
#   'changeBod': -0.006988793830581998,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 6423.0,
#   'priceLow24h': 6152.0},
#  {'name': 'XTZHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 65.03,
#   'bid': 66.85,
#   'ask': 67.685,
#   'price': 66.85,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.005726184279021343,
#   'change24h': 0.0039044901636882414,
#   'changeBod': 0.015186028853454821,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 67.445,
#   'priceLow24h': 65.03},
#  {'name': 'ZECBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 100.0,
#   'minProvideSize': 100.0,
#   'last': 0.003027,
#   'bid': 0.003032,
#   'ask': 0.003148,
#   'price': 0.003032,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ZECBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.031000319590923617,
#   'change24h': 0.001321003963011889,
#   'changeBod': 0.0016518004625041295,
#   'quoteVolume24h': 44.7996,
#   'volumeUsd24h': 44.7996,
#   'priceHigh24h': 0.00317,
#   'priceLow24h': 0.002995},
#  {'name': 'ZECBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 0.000143,
#   'bid': 0.0001486,
#   'ask': 0.00015035,
#   'price': 0.0001486,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ZECBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.027662517289073305,
#   'change24h': -0.012624584717607974,
#   'changeBod': -0.02907546553413917,
#   'quoteVolume24h': 321.49405,
#   'volumeUsd24h': 321.49405,
#   'priceHigh24h': 0.0001572,
#   'priceLow24h': 0.000143}]

# %%
df = pd.DataFrame(data)
df
# Out:
#              name  enabled  postOnly  priceIncrement  sizeIncrement  \
# 0      1INCH-PERP     True     False    1.000000e-04        1.00000
# 1      1INCH-0930     True     False    1.000000e-04        1.00000
# 2      1INCH-1230     True     False    1.000000e-04        1.00000
# 3       1INCH/USD     True     False    1.000000e-04        1.00000
# 4       AAPL-0930     True     False    1.000000e-02        0.01000
# ..            ...      ...       ...             ...            ...
# 931  XTZBULL/USDT     True     False    1.000000e-08    10000.00000
# 932   XTZHALF/USD     True     False    2.500000e-01        0.00001
# 933  XTZHEDGE/USD     True     False    5.000000e-03        0.00100
# 934   ZECBEAR/USD     True     False    1.000000e-06      100.00000
# 935   ZECBULL/USD     True     False    5.000000e-08     1000.00000
#
#      minProvideSize         last          bid          ask        price  ...  \
# 0           1.00000     0.578600     0.578800     0.578900     0.578800  ...
# 1           1.00000     0.576900     0.575900     0.579800     0.576900  ...
# 2           1.00000     0.561100     0.560700     0.561900     0.561100  ...
# 3           1.00000     0.578800     0.578900     0.579400     0.578900  ...
# 4           0.01000   143.710000   143.080000   143.250000   143.250000  ...
# ..              ...          ...          ...          ...          ...  ...
# 931     10000.00000     0.000019     0.000017     0.000019     0.000019  ...
# 932         0.00001  6423.000000  6133.500000  6180.750000  6180.750000  ...
# 933         0.00100    65.030000    66.850000    67.685000    66.850000  ...
# 934       100.00000     0.003027     0.003032     0.003148     0.003032  ...
# 935      1000.00000     0.000143     0.000149     0.000150     0.000149  ...
#
#     highLeverageFeeExempt largeOrderThreshold  change1h  change24h changeBod  \
# 0                   False               350.0  0.005734  -0.008734 -0.013633
# 1                   False               350.0  0.006982  -0.009274 -0.013171
# 2                   False               350.0  0.005556  -0.007781 -0.007956
# 3                    True               280.0  0.005558  -0.008903 -0.014135
# 4                   False               350.0  0.000489  -0.028550 -0.045255
# ..                    ...                 ...       ...        ...       ...
# 931                  True               196.0  0.021370   0.009204 -0.028661
# 932                  True               280.0  0.003002  -0.001817 -0.006989
# 933                  True               280.0 -0.005726   0.003904  0.015186
# 934                  True               280.0 -0.031000   0.001321  0.001652
# 935                  True               280.0  0.027663  -0.012625 -0.029075
#
#     quoteVolume24h  volumeUsd24h  priceHigh24h  priceLow24h  tokenizedEquity
# 0     3.018833e+06  3.018833e+06      0.593200     0.573200              NaN
# 1     7.546853e+03  7.546853e+03      0.589500     0.572100              NaN
# 2     1.004697e+04  1.004697e+04      0.572000     0.556200              NaN
# 3     1.305408e+06  1.305408e+06      0.593700     0.573300              NaN
# 4     4.714469e+05  4.714469e+05    150.730000   142.670000             True
# ..             ...           ...           ...          ...              ...
# 931   1.919000e-01  1.919000e-01      0.000019     0.000018              NaN
# 932   0.000000e+00  0.000000e+00   6423.000000  6152.000000              NaN
# 933   0.000000e+00  0.000000e+00     67.445000    65.030000              NaN
# 934   4.479960e+01  4.479960e+01      0.003170     0.002995              NaN
# 935   3.214941e+02  3.214941e+02      0.000157     0.000143              NaN
#
# [936 rows x 27 columns]

# %%
(df[df['name'] == 'BTC/USD']['change1h'].values)[0]
# Out:
# 0.015826958586125033

# %%
market_name = 'BTC/USD'
path = f'/markets/{market_name}'
url = api_url + path
url
# Out:
# 'https://ftx.com/api/markets/BTC/USD'

# %%
res = requests.get(url).json()
df = pd.DataFrame(res)['result']
df
# Out:
# ask                             19499.0
# baseCurrency                        BTC
# bid                             19498.0
# change1h                       0.003396
# change24h                      0.026479
# changeBod                      0.003035
# enabled                            True
# futureType                         None
# highLeverageFeeExempt              True
# isEtfMarket                       False
# largeOrderThreshold              2400.0
# last                            19499.0
# minProvideSize                   0.0001
# name                            BTC/USD
# postOnly                          False
# price                           19499.0
# priceHigh24h                    19767.0
# priceIncrement                      1.0
# priceLow24h                     18464.0
# quoteCurrency                       USD
# quoteVolume24h           889578152.9641
# restricted                        False
# sizeIncrement                    0.0001
# type                               spot
# underlying                         None
# volumeUsd24h             889578152.9641
# Name: result, dtype: object

# %%
resolution = 900
start_time = datetime.datetime(2022, 9, 28).timestamp()
path = f'/markets/{market_name}/candles?resolution={resolution}&start_time={start_time}'

# %%
url = api_url + path
res = requests.get(url).json()
df = pd.DataFrame(res['result'])
df
# Out:
#                     startTime          time     open     high      low  \
# 0   2022-09-28T05:00:00+00:00  1.664341e+12  18761.0  18773.0  18652.0
# 1   2022-09-28T05:15:00+00:00  1.664342e+12  18693.0  18765.0  18693.0
# 2   2022-09-28T05:30:00+00:00  1.664343e+12  18764.0  18809.0  18732.0
# 3   2022-09-28T05:45:00+00:00  1.664344e+12  18801.0  18832.0  18783.0
# 4   2022-09-28T06:00:00+00:00  1.664345e+12  18824.0  18883.0  18803.0
# ..                        ...           ...      ...      ...      ...
# 80  2022-09-29T01:00:00+00:00  1.664413e+12  19438.0  19466.0  19421.0
# 81  2022-09-29T01:15:00+00:00  1.664414e+12  19452.0  19521.0  19450.0
# 82  2022-09-29T01:30:00+00:00  1.664415e+12  19512.0  19596.0  19506.0
# 83  2022-09-29T01:45:00+00:00  1.664416e+12  19555.0  19574.0  19490.0
# 84  2022-09-29T02:00:00+00:00  1.664417e+12  19492.0  19500.0  19492.0
#
#       close        volume
# 0   18693.0  1.215158e+07
# 1   18764.0  5.305300e+06
# 2   18801.0  6.245727e+06
# 3   18823.0  2.841661e+06
# 4   18807.0  5.963039e+06
# ..      ...           ...
# 80  19452.0  2.786363e+06
# 81  19512.0  3.588505e+06
# 82  19555.0  4.603931e+06
# 83  19492.0  2.621898e+06
# 84  19492.0  9.032045e+04
#
# [85 rows x 7 columns]

# %%
df['date'] = pd.to_datetime(df['startTime'])
df = df.set_index('date')
df = df.drop(columns = ['startTime', 'time'])
df.head()
# Out:
#                              open    high     low   close        volume
# date
# 2022-02-02 00:00:00+00:00  2789.1  3286.5  2301.1  2948.6  1.296256e+10
# 2022-03-03 00:00:00+00:00  2948.7  3483.7  2444.7  3456.4  1.074473e+10
# 2022-04-02 00:00:00+00:00  3456.4  3581.4  2714.5  2824.4  9.239965e+09
# 2022-05-02 00:00:00+00:00  2824.4  2966.5  1700.0  1940.3  1.633315e+10
# 2022-06-01 00:00:00+00:00  1940.3  1971.5   880.0  1070.4  1.655756e+10

# %%
datetime(2022,1,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Sebastián\Documents\Henry\ZIPs Repos Alumnos\PI\PI-03-Dashboard\Acquisition\pruebas.ipynb Celda 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sebasti%C3%A1n/Documents/Henry/ZIPs%20Repos%20Alumnos/PI/PI-03-Dashboard/Acquisition/pruebas.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> datetime(2022,1,1)
#
# TypeError: 'module' object is not callable
