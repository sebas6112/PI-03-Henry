# %%
import datetime
import requests
import pandas as pd
# from client import FtxClient
# from local_settings import ftxus as settings

# %%
api_url = 'https://ftx.com/api'
api = "/markets"
url = api_url + api
url
# Out:
# 'https://ftx.com/api/markets'

# %%
markets = requests.get(url).json()
data = markets['result']
data
# Out:
# [{'name': '1INCH-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.5897,
#   'bid': 0.5896,
#   'ask': 0.5898,
#   'price': 0.5897,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': '1INCH',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.011145404663923183,
#   'change24h': -0.016511007338225483,
#   'changeBod': 0.004942058623040218,
#   'quoteVolume24h': 3980105.8824,
#   'volumeUsd24h': 3980105.8824,
#   'priceHigh24h': 0.6004,
#   'priceLow24h': 0.5744},
#  {'name': '1INCH-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.5895,
#   'bid': 0.5859,
#   'ask': 0.5884,
#   'price': 0.5884,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': '1INCH',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.012039903680770554,
#   'change24h': -0.009927645970048797,
#   'changeBod': 0.006500171057133082,
#   'quoteVolume24h': 9113.0773,
#   'volumeUsd24h': 9113.0773,
#   'priceHigh24h': 0.5954,
#   'priceLow24h': 0.572},
#  {'name': '1INCH-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.572,
#   'bid': 0.569,
#   'ask': 0.5714,
#   'price': 0.5714,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': '1INCH',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.013479957431713374,
#   'change24h': -0.01618457300275482,
#   'changeBod': 0.010254596888260255,
#   'quoteVolume24h': 13491.5775,
#   'volumeUsd24h': 13491.5775,
#   'priceHigh24h': 0.582,
#   'priceLow24h': 0.5564},
#  {'name': '1INCH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.59,
#   'bid': 0.5902,
#   'ask': 0.5907,
#   'price': 0.5902,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': '1INCH',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.01044341722307824,
#   'change24h': -0.016497250458256958,
#   'changeBod': 0.005108991825613079,
#   'quoteVolume24h': 1550202.0227,
#   'volumeUsd24h': 1550202.0227,
#   'priceHigh24h': 0.6011,
#   'priceLow24h': 0.5745},
#  {'name': 'AAPL-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 150.04,
#   'bid': 149.23,
#   'ask': 149.79,
#   'price': 149.79,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAPL',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.0016662223407091442,
#   'change24h': -0.003989626969878316,
#   'changeBod': -0.0016662223407091442,
#   'quoteVolume24h': 83919.6428,
#   'volumeUsd24h': 83919.6428,
#   'priceHigh24h': 150.73,
#   'priceLow24h': 145.13},
#  {'name': 'AAPL-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 149.5,
#   'bid': 149.5,
#   'ask': 149.63,
#   'price': 149.5,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAPL',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0,
#   'change24h': -0.005719606278265496,
#   'changeBod': 0.0,
#   'quoteVolume24h': 78817.2528,
#   'volumeUsd24h': 78817.2528,
#   'priceHigh24h': 150.61,
#   'priceLow24h': 144.63},
#  {'name': 'AAPL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 149.91,
#   'bid': 149.64,
#   'ask': 149.68,
#   'price': 149.68,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAPL',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0002673082063619353,
#   'change24h': -0.006768414067684141,
#   'changeBod': 0.0002673082063619353,
#   'quoteVolume24h': 264661.6103,
#   'volumeUsd24h': 264661.6103,
#   'priceHigh24h': 152.37,
#   'priceLow24h': 145.06},
#  {'name': 'AAVE-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 77.1,
#   'bid': 77.14,
#   'ask': 77.16,
#   'price': 77.14,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAVE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.011672131147540983,
#   'change24h': 0.01781237630294234,
#   'changeBod': 0.0,
#   'quoteVolume24h': 13782538.3501,
#   'volumeUsd24h': 13782538.3501,
#   'priceHigh24h': 77.72,
#   'priceLow24h': 72.97},
#  {'name': 'AAVE-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 74.44,
#   'bid': 77.06,
#   'ask': 77.41,
#   'price': 77.06,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAVE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.011418821367633548,
#   'change24h': 0.0197168188434564,
#   'changeBod': 0.0010392309690828788,
#   'quoteVolume24h': 753.6896,
#   'volumeUsd24h': 753.6896,
#   'priceHigh24h': 77.57,
#   'priceLow24h': 73.41},
#  {'name': 'AAVE-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 76.87,
#   'bid': 76.44,
#   'ask': 77.08,
#   'price': 76.87,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAVE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.010915307732772226,
#   'change24h': 0.015724101479915435,
#   'changeBod': 0.0027393686407513698,
#   'quoteVolume24h': 15044.2282,
#   'volumeUsd24h': 15044.2282,
#   'priceHigh24h': 76.98,
#   'priceLow24h': 71.29},
#  {'name': 'AAVE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 77.19,
#   'bid': 77.08,
#   'ask': 77.16,
#   'price': 77.16,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': 0.011536444677503933,
#   'change24h': 0.018076263359282228,
#   'changeBod': 0.00012961762799740766,
#   'quoteVolume24h': 1424924.7429,
#   'volumeUsd24h': 1424924.7429,
#   'priceHigh24h': 77.73,
#   'priceLow24h': 73.0},
#  {'name': 'AAVE/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 77.37,
#   'bid': 77.08,
#   'ask': 77.21,
#   'price': 77.21,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': 0.011661425576519916,
#   'change24h': 0.017795939889269707,
#   'changeBod': 0.0005183361409874304,
#   'quoteVolume24h': 103307.1192,
#   'volumeUsd24h': 103296.78848808,
#   'priceHigh24h': 77.75,
#   'priceLow24h': 73.0},
#  {'name': 'ABNB-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.025,
#   'minProvideSize': 0.025,
#   'last': 110.03,
#   'bid': 110.45,
#   'ask': 110.88,
#   'price': 110.45,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ABNB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.0012207803951711353,
#   'change24h': 0.0435070149747272,
#   'changeBod': 0.000770171702985548,
#   'quoteVolume24h': 16240.247875,
#   'volumeUsd24h': 16240.247875,
#   'priceHigh24h': 111.26,
#   'priceLow24h': 104.42},
#  {'name': 'ABNB-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.025,
#   'minProvideSize': 0.025,
#   'last': 109.0,
#   'bid': 110.55,
#   'ask': 110.87,
#   'price': 110.55,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ABNB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.001039172276690914,
#   'change24h': 0.03173121791880541,
#   'changeBod': 0.0008147745790331341,
#   'quoteVolume24h': 327.0,
#   'volumeUsd24h': 327.0,
#   'priceHigh24h': 111.325,
#   'priceLow24h': 104.39},
#  {'name': 'ABNB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.025,
#   'minProvideSize': 0.025,
#   'last': 110.445,
#   'bid': 110.43,
#   'ask': 110.8,
#   'price': 110.445,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ABNB',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0009046089827671989,
#   'change24h': 0.033065195023851836,
#   'changeBod': -0.00018105282216086544,
#   'quoteVolume24h': 2950.83275,
#   'volumeUsd24h': 2950.83275,
#   'priceHigh24h': 111.2,
#   'priceLow24h': 104.21},
#  {'name': 'ACB-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.302,
#   'bid': 1.302,
#   'ask': 1.314,
#   'price': 1.302,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ACB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.0015337423312883436,
#   'change24h': 0.07870753935376967,
#   'changeBod': 0.0,
#   'quoteVolume24h': 3035.4338,
#   'volumeUsd24h': 3035.4338,
#   'priceHigh24h': 1.307,
#   'priceLow24h': 1.206},
#  {'name': 'ACB-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.29,
#   'bid': 1.232,
#   'ask': 1.34,
#   'price': 1.29,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ACB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0,
#   'change24h': 0.032,
#   'changeBod': 0.0,
#   'quoteVolume24h': 7361.3814,
#   'volumeUsd24h': 7361.3814,
#   'priceHigh24h': 1.308,
#   'priceLow24h': 1.151},
#  {'name': 'ACB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.292,
#   'bid': 1.305,
#   'ask': 1.314,
#   'price': 1.305,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ACB',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0007668711656441718,
#   'change24h': 0.0811930405965203,
#   'changeBod': 0.0,
#   'quoteVolume24h': 21600.7513,
#   'volumeUsd24h': 21600.7513,
#   'priceHigh24h': 1.309,
#   'priceLow24h': 1.189},
#  {'name': 'ADA-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.43664,
#   'bid': 0.43661,
#   'ask': 0.436655,
#   'price': 0.43664,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ADA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.003677822728944465,
#   'change24h': 0.006256841620095639,
#   'changeBod': -0.00162341374185435,
#   'quoteVolume24h': 42729833.09928,
#   'volumeUsd24h': 42729833.09928,
#   'priceHigh24h': 0.440575,
#   'priceLow24h': 0.42463},
#  {'name': 'ADA-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.435905,
#   'bid': 0.435355,
#   'ask': 0.435715,
#   'price': 0.435715,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ADA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.00473873541484112,
#   'change24h': 0.006851530906990179,
#   'changeBod': -0.000928643492616711,
#   'quoteVolume24h': 489817.12276,
#   'volumeUsd24h': 489817.12276,
#   'priceHigh24h': 0.43932,
#   'priceLow24h': 0.42424},
#  {'name': 'ADA-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.426845,
#   'bid': 0.426845,
#   'ask': 0.427965,
#   'price': 0.426845,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ADA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.0035855355967271702,
#   'change24h': 0.008910949595225433,
#   'changeBod': -0.00067894225479064,
#   'quoteVolume24h': 23305.630165,
#   'volumeUsd24h': 23305.630165,
#   'priceHigh24h': 0.431535,
#   'priceLow24h': 0.415045},
#  {'name': 'AGLD-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.3205,
#   'bid': 0.3205,
#   'ask': 0.321,
#   'price': 0.3205,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AGLD',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.009448818897637795,
#   'change24h': 0.0256,
#   'changeBod': 0.011041009463722398,
#   'quoteVolume24h': 2637263.7812,
#   'volumeUsd24h': 2637263.7812,
#   'priceHigh24h': 0.322,
#   'priceLow24h': 0.304},
#  {'name': 'AGLD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.3215,
#   'bid': 0.32,
#   'ask': 0.322,
#   'price': 0.3215,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AGLD',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.014195583596214511,
#   'change24h': 0.03210272873194221,
#   'changeBod': 0.014195583596214511,
#   'quoteVolume24h': 188326.7413,
#   'volumeUsd24h': 188326.7413,
#   'priceHigh24h': 0.3215,
#   'priceLow24h': 0.304},
#  {'name': 'AKRO/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.00397,
#   'bid': 0.00396,
#   'ask': 0.003975,
#   'price': 0.00397,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AKRO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0063371356147021544,
#   'change24h': 0.019255455712451863,
#   'changeBod': 0.0037926675094816687,
#   'quoteVolume24h': 3185.64341,
#   'volumeUsd24h': 3185.64341,
#   'priceHigh24h': 0.00408,
#   'priceLow24h': 0.00377},
#  {'name': 'AKRO/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.00398,
#   'bid': 0.00397,
#   'ask': 0.003985,
#   'price': 0.00398,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AKRO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.006321112515802781,
#   'change24h': 0.019206145966709345,
#   'changeBod': 0.006321112515802781,
#   'quoteVolume24h': 1819.58,
#   'volumeUsd24h': 1819.398042,
#   'priceHigh24h': 0.004075,
#   'priceLow24h': 0.003775},
#  {'name': 'ALCX-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 20.7,
#   'bid': 20.7,
#   'ask': 20.8,
#   'price': 20.7,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALCX',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.00975609756097561,
#   'change24h': 0.04020100502512563,
#   'changeBod': 0.0048543689320388345,
#   'quoteVolume24h': 334572.5483,
#   'volumeUsd24h': 334572.5483,
#   'priceHigh24h': 21.1,
#   'priceLow24h': 19.6},
#  {'name': 'ALCX/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 20.8,
#   'bid': 20.7,
#   'ask': 20.9,
#   'price': 20.8,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALCX',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.009708737864077669,
#   'change24h': 0.04,
#   'changeBod': 0.009708737864077669,
#   'quoteVolume24h': 14626.6627,
#   'volumeUsd24h': 14626.6627,
#   'priceHigh24h': 21.0,
#   'priceLow24h': 19.7},
#  {'name': 'ALEPH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.1186,
#   'bid': 0.1183,
#   'ask': 0.1186,
#   'price': 0.1186,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALEPH',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0041981528127623844,
#   'change24h': 0.0076465590484282074,
#   'changeBod': -0.0050335570469798654,
#   'quoteVolume24h': 47764.47295,
#   'volumeUsd24h': 47764.47295,
#   'priceHigh24h': 0.1209,
#   'priceLow24h': 0.11595},
#  {'name': 'ALGO-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3627,
#   'bid': 0.3628,
#   'ask': 0.3629,
#   'price': 0.3628,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALGO',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.021971830985915493,
#   'change24h': 0.05896088733216579,
#   'changeBod': 0.03420752565564424,
#   'quoteVolume24h': 26205574.2946,
#   'volumeUsd24h': 26205574.2946,
#   'priceHigh24h': 0.3639,
#   'priceLow24h': 0.332},
#  {'name': 'ALGO-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3581,
#   'bid': 0.3622,
#   'ask': 0.3642,
#   'price': 0.3622,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALGO',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.01856017997750281,
#   'change24h': 0.0535194880744619,
#   'changeBod': 0.0345615538417595,
#   'quoteVolume24h': 11859.5695,
#   'volumeUsd24h': 11859.5695,
#   'priceHigh24h': 0.3634,
#   'priceLow24h': 0.3333},
#  {'name': 'ALGO-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3642,
#   'bid': 0.3628,
#   'ask': 0.3663,
#   'price': 0.3642,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALGO',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.021026072329688814,
#   'change24h': 0.05442964678633468,
#   'changeBod': 0.03583617747440273,
#   'quoteVolume24h': 47153.1009,
#   'volumeUsd24h': 47153.1009,
#   'priceHigh24h': 0.3642,
#   'priceLow24h': 0.3352},
#  {'name': 'ALGO/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3632,
#   'bid': 0.3625,
#   'ask': 0.3631,
#   'price': 0.3631,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': 0.022528865108420164,
#   'change24h': 0.059836544074722706,
#   'changeBod': 0.0356531660011409,
#   'quoteVolume24h': 799814.2834,
#   'volumeUsd24h': 799814.2834,
#   'priceHigh24h': 0.3635,
#   'priceLow24h': 0.3322},
#  {'name': 'ALGO/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3634,
#   'bid': 0.3623,
#   'ask': 0.3629,
#   'price': 0.3629,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': 0.020528683914510685,
#   'change24h': 0.06049094097019287,
#   'changeBod': 0.035082715345122646,
#   'quoteVolume24h': 94109.1019,
#   'volumeUsd24h': 94099.69098981,
#   'priceHigh24h': 0.3634,
#   'priceLow24h': 0.3322},
#  {'name': 'ALICE-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.7075,
#   'bid': 1.705,
#   'ask': 1.7075,
#   'price': 1.7075,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALICE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.011851851851851851,
#   'change24h': 0.03172205438066465,
#   'changeBod': 0.002936857562408223,
#   'quoteVolume24h': 1127533.53675,
#   'volumeUsd24h': 1127533.53675,
#   'priceHigh24h': 1.7125,
#   'priceLow24h': 1.605},
#  {'name': 'ALICE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.705,
#   'bid': 1.705,
#   'ask': 1.71,
#   'price': 1.705,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALICE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.008875739644970414,
#   'change24h': 0.03333333333333333,
#   'changeBod': -0.0014641288433382138,
#   'quoteVolume24h': 5424.79175,
#   'volumeUsd24h': 5424.79175,
#   'priceHigh24h': 1.71,
#   'priceLow24h': 1.6075},
#  {'name': 'ALPHA-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.11165,
#   'bid': 0.1116,
#   'ask': 0.1117,
#   'price': 0.11165,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALPHA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.00449842555105713,
#   'change24h': 0.06383992377322535,
#   'changeBod': 0.0013452914798206279,
#   'quoteVolume24h': 1395341.28075,
#   'volumeUsd24h': 1395341.28075,
#   'priceHigh24h': 0.1134,
#   'priceLow24h': 0.1022},
#  {'name': 'ALPHA/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.11175,
#   'bid': 0.11145,
#   'ask': 0.11165,
#   'price': 0.11165,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALPHA',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0049504950495049506,
#   'change24h': 0.06383992377322535,
#   'changeBod': 0.002694207453973956,
#   'quoteVolume24h': 221833.7005,
#   'volumeUsd24h': 221833.7005,
#   'priceHigh24h': 0.1133,
#   'priceLow24h': 0.1023},
#  {'name': 'ALT-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.05,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1867.6,
#   'bid': 1867.6,
#   'ask': 1867.85,
#   'price': 1867.6,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALT',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 600.0,
#   'change1h': 0.005545684595918807,
#   'change24h': 0.030997267382483647,
#   'changeBod': 0.000911088482769709,
#   'quoteVolume24h': 3972337.5715,
#   'volumeUsd24h': 3972337.5715,
#   'priceHigh24h': 1872.4,
#   'priceLow24h': 1775.3},
#  {'name': 'ALT-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.05,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1859.2,
#   'bid': 1864.9,
#   'ask': 1867.2,
#   'price': 1864.9,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALT',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 600.0,
#   'change1h': 0.005011856003449019,
#   'change24h': 0.029080675422138838,
#   'changeBod': 5.3625053625053626e-05,
#   'quoteVolume24h': 491652.02405,
#   'volumeUsd24h': 491652.02405,
#   'priceHigh24h': 1870.55,
#   'priceLow24h': 1776.8},
#  {'name': 'ALT-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.05,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1840.65,
#   'bid': 1833.95,
#   'ask': 1836.75,
#   'price': 1836.75,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALT',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 600.0,
#   'change1h': 0.0037708008853184686,
#   'change24h': 0.033275202520252026,
#   'changeBod': 0.002674891503125256,
#   'quoteVolume24h': 480141.08415,
#   'volumeUsd24h': 480141.08415,
#   'priceHigh24h': 1841.95,
#   'priceLow24h': 1733.45},
#  {'name': 'AMC-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 13.5525,
#   'bid': 13.5425,
#   'ask': 13.95,
#   'price': 13.5525,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMC',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0,
#   'change24h': 0.022830188679245283,
#   'changeBod': 0.0,
#   'quoteVolume24h': 528.455,
#   'volumeUsd24h': 528.455,
#   'priceHigh24h': 13.9175,
#   'priceLow24h': 13.08},
#  {'name': 'AMC-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 7.6175,
#   'bid': 7.6325,
#   'ask': 7.7425,
#   'price': 7.6325,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMC',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0,
#   'change24h': 0.027946127946127945,
#   'changeBod': 0.000327653997378768,
#   'quoteVolume24h': 1814.3,
#   'volumeUsd24h': 1814.3,
#   'priceHigh24h': 7.7175,
#   'priceLow24h': 7.195},
#  {'name': 'AMC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 7.7725,
#   'bid': 7.6,
#   'ask': 7.7375,
#   'price': 7.7375,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMC',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.01608667104399212,
#   'change24h': 0.04068594485541358,
#   'changeBod': 0.016754270696452037,
#   'quoteVolume24h': 4964.60125,
#   'volumeUsd24h': 4964.60125,
#   'priceHigh24h': 7.7725,
#   'priceLow24h': 7.2},
#  {'name': 'AMD-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 67.74,
#   'bid': 68.07,
#   'ask': 69.02,
#   'price': 68.07,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMD',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.0017597888253409592,
#   'change24h': 0.020539730134932533,
#   'changeBod': -0.0027834749487254617,
#   'quoteVolume24h': 5783.7778,
#   'volumeUsd24h': 5783.7778,
#   'priceHigh24h': 68.88,
#   'priceLow24h': 65.95},
#  {'name': 'AMD-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 68.13,
#   'bid': 68.14,
#   'ask': 68.97,
#   'price': 68.14,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMD',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.0016117216117216117,
#   'change24h': 0.02158920539730135,
#   'changeBod': 0.0001467782181124321,
#   'quoteVolume24h': 6692.3006,
#   'volumeUsd24h': 6692.3006,
#   'priceHigh24h': 68.91,
#   'priceLow24h': 65.94},
#  {'name': 'AMD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 68.63,
#   'bid': 68.09,
#   'ask': 68.63,
#   'price': 68.63,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMD',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': 0.02097590002975305,
#   'changeBod': 0.0061574549186336315,
#   'quoteVolume24h': 846.1712,
#   'volumeUsd24h': 846.1712,
#   'priceHigh24h': 68.84,
#   'priceLow24h': 65.88},
#  {'name': 'AMPL-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 1.1386,
#   'bid': 1.1358,
#   'ask': 1.1386,
#   'price': 1.1386,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMPL',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0002635509092506369,
#   'change24h': 0.031060400253554287,
#   'changeBod': -0.005849995634331616,
#   'quoteVolume24h': 141299.097,
#   'volumeUsd24h': 141299.097,
#   'priceHigh24h': 1.1558,
#   'priceLow24h': 1.0676},
#  {'name': 'AMPL/USD',
#   'enabled': True,
#   'postOnly': True,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 1.1385,
#   'bid': 1.1396,
#   'ask': 1.1502,
#   'price': 1.1396,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMPL',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.000966183574879227,
#   'change24h': 0.02389937106918239,
#   'changeBod': -0.008871108018785876,
#   'quoteVolume24h': 81171.2471,
#   'volumeUsd24h': 81171.2471,
#   'priceHigh24h': 1.18,
#   'priceLow24h': 1.0661},
#  {'name': 'AMPL/USDT',
#   'enabled': True,
#   'postOnly': True,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 1.1431,
#   'bid': 1.1444,
#   'ask': 1.1518,
#   'price': 1.1444,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMPL',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0011372583326043216,
#   'change24h': 0.02599964138425677,
#   'changeBod': -0.006079555323953448,
#   'quoteVolume24h': 44150.1765,
#   'volumeUsd24h': 44145.76148235,
#   'priceHigh24h': 1.1633,
#   'priceLow24h': 1.0662},
#  {'name': 'AMZN-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 115.0,
#   'bid': 117.1,
#   'ask': 118.3,
#   'price': 117.1,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMZN',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0,
#   'change24h': 0.024496937882764653,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 118.2,
#   'priceLow24h': 112.1},
#  {'name': 'AMZN-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 116.7,
#   'bid': 116.7,
#   'ask': 118.2,
#   'price': 116.7,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMZN',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0008576329331046312,
#   'change24h': 0.030918727915194347,
#   'changeBod': 0.0,
#   'quoteVolume24h': 10649.7992,
#   'volumeUsd24h': 10649.7992,
#   'priceHigh24h': 118.2,
#   'priceLow24h': 110.6},
#  {'name': 'AMZN/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 117.5,
#   'bid': 117.4,
#   'ask': 117.7,
#   'price': 117.5,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMZN',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': 0.03251318101933216,
#   'changeBod': 0.0,
#   'quoteVolume24h': 12637.8844,
#   'volumeUsd24h': 12637.8844,
#   'priceHigh24h': 118.2,
#   'priceLow24h': 112.0},
#  {'name': 'APE-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.427,
#   'bid': 5.4255,
#   'ask': 5.4265,
#   'price': 5.4265,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'APE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.015342875853681355,
#   'change24h': 0.013257398935673606,
#   'changeBod': 0.006958619409909074,
#   'quoteVolume24h': 23704591.4641,
#   'volumeUsd24h': 23704591.4641,
#   'priceHigh24h': 5.454,
#   'priceLow24h': 5.2115},
#  {'name': 'APE-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.4235,
#   'bid': 5.409,
#   'ask': 5.4285,
#   'price': 5.4235,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'APE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.014401945197792948,
#   'change24h': 0.01630282020050595,
#   'changeBod': 0.006308562946469988,
#   'quoteVolume24h': 258.6075,
#   'volumeUsd24h': 258.6075,
#   'priceHigh24h': 5.4365,
#   'priceLow24h': 5.2155},
#  {'name': 'APE-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.277,
#   'bid': 5.2915,
#   'ask': 5.312,
#   'price': 5.2915,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'APE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.011759082217973232,
#   'change24h': 0.010406721405384763,
#   'changeBod': 0.005128692183493209,
#   'quoteVolume24h': 9756.4288,
#   'volumeUsd24h': 9756.4288,
#   'priceHigh24h': 5.317,
#   'priceLow24h': 5.1075},
#  {'name': 'APE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.4275,
#   'bid': 5.4255,
#   'ask': 5.4275,
#   'price': 5.4275,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'APE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.015434985968194575,
#   'change24h': 0.013444122864345065,
#   'changeBod': 0.007144182594173316,
#   'quoteVolume24h': 2722120.18535,
#   'volumeUsd24h': 2722120.18535,
#   'priceHigh24h': 5.453,
#   'priceLow24h': 5.2155},
#  {'name': 'APEAMC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 3.3225,
#   'bid': 3.355,
#   'ask': 3.395,
#   'price': 3.355,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'APEAMC',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0029895366218236174,
#   'change24h': -0.018288222384784197,
#   'changeBod': 0.0029895366218236174,
#   'quoteVolume24h': 210.1125,
#   'volumeUsd24h': 210.1125,
#   'priceHigh24h': 3.4675,
#   'priceLow24h': 3.2275},
#  {'name': 'APHA/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 2.515,
#   'bid': 2.514,
#   'ask': 2.523,
#   'price': 2.515,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'APHA',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0011914217633042098,
#   'change24h': 0.057166876839007986,
#   'changeBod': -0.001984126984126984,
#   'quoteVolume24h': 182.589,
#   'volumeUsd24h': 182.589,
#   'priceHigh24h': 2.538,
#   'priceLow24h': 2.298},
#  {'name': 'AR-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 9.317,
#   'bid': 9.313,
#   'ask': 9.318,
#   'price': 9.317,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AR',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.00964456003467707,
#   'change24h': 0.009535160905840286,
#   'changeBod': -0.0015003750937734434,
#   'quoteVolume24h': 2389301.6225,
#   'volumeUsd24h': 2389301.6225,
#   'priceHigh24h': 9.446,
#   'priceLow24h': 8.978},
#  {'name': 'ARKK-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 39.79,
#   'bid': 39.89,
#   'ask': 40.05,
#   'price': 39.89,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ARKK',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.001501877346683354,
#   'change24h': 0.02968508002065049,
#   'changeBod': -0.0022511255627813906,
#   'quoteVolume24h': 12065.5489,
#   'volumeUsd24h': 12065.5489,
#   'priceHigh24h': 40.36,
#   'priceLow24h': 37.51},
#  {'name': 'ARKK-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 39.8,
#   'bid': 39.93,
#   'ask': 40.06,
#   'price': 39.93,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ARKK',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.0015003750937734434,
#   'change24h': 0.030983733539891558,
#   'changeBod': 0.0012537612838515546,
#   'quoteVolume24h': 91122.5472,
#   'volumeUsd24h': 91122.5472,
#   'priceHigh24h': 40.39,
#   'priceLow24h': 37.51},
#  {'name': 'ARKK/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 40.07,
#   'bid': 39.9,
#   'ask': 40.01,
#   'price': 40.01,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ARKK',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0014973795857249812,
#   'change24h': 0.04084287200832466,
#   'changeBod': -0.0014973795857249812,
#   'quoteVolume24h': 18964.1336,
#   'volumeUsd24h': 18964.1336,
#   'priceHigh24h': 40.35,
#   'priceLow24h': 37.47},
#  {'name': 'ASD-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.11061,
#   'bid': 0.11019,
#   'ask': 0.11048,
#   'price': 0.11048,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ASD',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.005826656955571741,
#   'change24h': 0.040889391369888825,
#   'changeBod': 0.0034514078110808354,
#   'quoteVolume24h': 225123.807043,
#   'volumeUsd24h': 225123.807043,
#   'priceHigh24h': 0.111,
#   'priceLow24h': 0.10591},
#  {'name': 'ASD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.11021,
#   'bid': 0.11021,
#   'ask': 0.11051,
#   'price': 0.11021,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ASD',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0017269587347754954,
#   'change24h': 0.03688023332392511,
#   'changeBod': 0.004923862496580651,
#   'quoteVolume24h': 81361.277969,
#   'volumeUsd24h': 81361.277969,
#   'priceHigh24h': 0.11122,
#   'priceLow24h': 0.10569},
#  {'name': 'ATLAS-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.00446725,
#   'bid': 0.00446725,
#   'ask': 0.004479,
#   'price': 0.00446725,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATLAS',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.004892588010347542,
#   'change24h': 0.008807090837238187,
#   'changeBod': -0.0037355040142729706,
#   'quoteVolume24h': 235059.9502625,
#   'volumeUsd24h': 235059.9502625,
#   'priceHigh24h': 0.0045725,
#   'priceLow24h': 0.00428375},
#  {'name': 'ATLAS/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.00446075,
#   'bid': 0.00446075,
#   'ask': 0.00446675,
#   'price': 0.00446075,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ATLAS',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0042775932909326275,
#   'change24h': 0.007965201672127444,
#   'changeBod': -0.006293161060369793,
#   'quoteVolume24h': 190270.890425,
#   'volumeUsd24h': 190270.890425,
#   'priceHigh24h': 0.00457775,
#   'priceLow24h': 0.00430025},
#  {'name': 'ATOM-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 12.93,
#   'bid': 12.93,
#   'ask': 12.9305,
#   'price': 12.93,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATOM',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.01352145796590241,
#   'change24h': -0.018484077883630014,
#   'changeBod': -0.0010815822002472187,
#   'quoteVolume24h': 155732259.34165,
#   'volumeUsd24h': 155732259.34165,
#   'priceHigh24h': 13.32,
#   'priceLow24h': 12.6055},
#  {'name': 'ATOM-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 12.9595,
#   'bid': 12.92,
#   'ask': 12.951,
#   'price': 12.951,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATOM',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.01576470588235294,
#   'change24h': -0.012617695269317272,
#   'changeBod': 0.001314365238905211,
#   'quoteVolume24h': 9928.67599,
#   'volumeUsd24h': 9928.67599,
#   'priceHigh24h': 13.2735,
#   'priceLow24h': 12.626},
#  {'name': 'ATOM-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 12.564,
#   'bid': 12.558,
#   'ask': 12.6325,
#   'price': 12.564,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATOM',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.013184952219668561,
#   'change24h': -0.015128948812416712,
#   'changeBod': -0.00031826861871419476,
#   'quoteVolume24h': 355183.777025,
#   'volumeUsd24h': 355183.777025,
#   'priceHigh24h': 12.9215,
#   'priceLow24h': 12.285},
#  {'name': 'ATOM/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 12.945,
#   'bid': 12.945,
#   'ask': 12.95,
#   'price': 12.945,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ATOM',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.013505578391074574,
#   'change24h': -0.016710976072920623,
#   'changeBod': -0.001735106998264893,
#   'quoteVolume24h': 15703761.31175,
#   'volumeUsd24h': 15703761.31175,
#   'priceHigh24h': 13.3175,
#   'priceLow24h': 12.62},
#  {'name': 'ATOM/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 12.9375,
#   'bid': 12.9425,
#   'ask': 12.9575,
#   'price': 12.9425,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ATOM',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': 0.013111545988258318,
#   'change24h': -0.01727410782080486,
#   'changeBod': -0.0015429122468659595,
#   'quoteVolume24h': 583907.522,
#   'volumeUsd24h': 583849.1312478,
#   'priceHigh24h': 13.32,
#   'priceLow24h': 12.625},
#  {'name': 'AUDIO-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.216,
#   'bid': 0.2155,
#   'ask': 0.216,
#   'price': 0.216,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AUDIO',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
# ...
#   'volumeUsd24h': 356.946,
#   'priceHigh24h': 1.83e-06,
#   'priceLow24h': 1.59e-06},
#  {'name': 'VETBEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 100000.0,
#   'minProvideSize': 100000.0,
#   'last': 1.63e-06,
#   'bid': 1.59e-06,
#   'ask': 1.62e-06,
#   'price': 1.62e-06,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -0.006134969325153374,
#   'change24h': -0.06358381502890173,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 1.83e-06,
#   'priceLow24h': 1.59e-06},
#  {'name': 'VETBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 8.814e-05,
#   'bid': 8.753e-05,
#   'ask': 8.844e-05,
#   'price': 8.814e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.025718608169440244,
#   'change24h': 0.0973605577689243,
#   'changeBod': 0.0012495740088606156,
#   'quoteVolume24h': 3409.89746,
#   'volumeUsd24h': 3409.89746,
#   'priceHigh24h': 8.916e-05,
#   'priceLow24h': 7.576e-05},
#  {'name': 'VETBULL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 8.849e-05,
#   'bid': 8.727e-05,
#   'ask': 8.852e-05,
#   'price': 8.849e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.01817972615349212,
#   'change24h': 0.09139121854958066,
#   'changeBod': -0.003041910770617395,
#   'quoteVolume24h': 82.93089,
#   'volumeUsd24h': 82.922596911,
#   'priceHigh24h': 8.895e-05,
#   'priceLow24h': 7.63e-05},
#  {'name': 'VETHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 100.5,
#   'bid': 98.5,
#   'ask': 99.5,
#   'price': 99.5,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.005,
#   'change24h': -0.019704433497536946,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 103.0,
#   'priceLow24h': 99.0},
#  {'name': 'XAUTBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 5665.0,
#   'bid': 5562.5,
#   'ask': 5645.0,
#   'price': 5645.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.00353045013239188,
#   'change24h': -0.03792074989348104,
#   'changeBod': -0.00353045013239188,
#   'quoteVolume24h': 1097.8789,
#   'volumeUsd24h': 1097.8789,
#   'priceHigh24h': 5997.5,
#   'priceLow24h': 5597.5},
#  {'name': 'XAUTBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 4425.0,
#   'bid': 4696.0,
#   'ask': 4765.0,
#   'price': 4696.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.003847798204360838,
#   'change24h': 0.038708250387082505,
#   'changeBod': 0.001492855619535082,
#   'quoteVolume24h': 0.04425,
#   'volumeUsd24h': 0.04425,
#   'priceHigh24h': 4720.0,
#   'priceLow24h': 4422.0},
#  {'name': 'XAUTHALF/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.25,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 5657.25,
#   'bid': 5648.0,
#   'ask': 5667.5,
#   'price': 5657.25,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTHALF',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': 0.006807261078483716,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 5657.25,
#   'priceLow24h': 5598.75},
#  {'name': 'XAUTHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 4926.5,
#   'bid': 4885.5,
#   'ask': 4918.0,
#   'price': 4918.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0009141696292534282,
#   'change24h': -0.011755249673465288,
#   'changeBod': -0.000609632188579557,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 5013.0,
#   'priceLow24h': 4908.0},
#  {'name': 'XLMBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.0103325,
#   'bid': 0.0102175,
#   'ask': 0.0103775,
#   'price': 0.0103325,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XLMBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0028950542822677927,
#   'change24h': -0.00529482551143201,
#   'changeBod': 0.0,
#   'quoteVolume24h': 39.696025,
#   'volumeUsd24h': 39.696025,
#   'priceHigh24h': 0.0108825,
#   'priceLow24h': 0.010015},
#  {'name': 'XLMBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-07,
#   'sizeIncrement': 100.0,
#   'minProvideSize': 100.0,
#   'last': 0.002019,
#   'bid': 0.0020255,
#   'ask': 0.0020585,
#   'price': 0.0020255,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XLMBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0032194155522535907,
#   'change24h': 0.008715139442231075,
#   'changeBod': -0.010503175378602833,
#   'quoteVolume24h': 150974.65715,
#   'volumeUsd24h': 150974.65715,
#   'priceHigh24h': 0.0021065,
#   'priceLow24h': 0.0019305},
#  {'name': 'XRPBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000000.0,
#   'minProvideSize': 10000000.0,
#   'last': 5e-08,
#   'bid': 5e-08,
#   'ask': 7e-08,
#   'price': 5e-08,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 5e-08,
#   'priceLow24h': 5e-08},
#  {'name': 'XRPBEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000000.0,
#   'minProvideSize': 10000000.0,
#   'last': 9e-08,
#   'bid': 5e-08,
#   'ask': 1.7e-07,
#   'price': 9e-08,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 9e-08,
#   'priceLow24h': 9e-08},
#  {'name': 'XRPBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 3.069e-05,
#   'bid': 3.052e-05,
#   'ask': 3.075e-05,
#   'price': 3.069e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.011869436201780416,
#   'change24h': 0.12048192771084337,
#   'changeBod': -0.013500482160077145,
#   'quoteVolume24h': 145927.33652,
#   'volumeUsd24h': 145927.33652,
#   'priceHigh24h': 3.264e-05,
#   'priceLow24h': 2.437e-05},
#  {'name': 'XRPBULL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 3.075e-05,
#   'bid': 3.041e-05,
#   'ask': 3.079e-05,
#   'price': 3.075e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0006508298080052066,
#   'change24h': 0.12926918839515242,
#   'changeBod': -0.02411932719771501,
#   'quoteVolume24h': 7334.52186,
#   'volumeUsd24h': 7333.788407814,
#   'priceHigh24h': 3.209e-05,
#   'priceLow24h': 2.479e-05},
#  {'name': 'XRPHALF/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 12815.5,
#   'bid': 12801.0,
#   'ask': 12827.5,
#   'price': 12815.5,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPHALF',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': 0.016256294357876372,
#   'changeBod': -0.00500776397515528,
#   'quoteVolume24h': 15.12229,
#   'volumeUsd24h': 15.12229,
#   'priceHigh24h': 13005.0,
#   'priceLow24h': 12410.5},
#  {'name': 'XRPHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 45.29,
#   'bid': 45.46,
#   'ask': 45.64,
#   'price': 45.46,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.001098659635245001,
#   'change24h': -0.03563852354688163,
#   'changeBod': 0.003753587988518437,
#   'quoteVolume24h': 7946.32799,
#   'volumeUsd24h': 7946.32799,
#   'priceHigh24h': 48.465,
#   'priceLow24h': 44.825},
#  {'name': 'XTZBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000000.0,
#   'minProvideSize': 1000000.0,
#   'last': 1.4e-07,
#   'bid': 1.3e-07,
#   'ask': 1.5e-07,
#   'price': 1.4e-07,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.06666666666666667,
#   'changeBod': -0.06666666666666667,
#   'quoteVolume24h': 12.47,
#   'volumeUsd24h': 12.47,
#   'priceHigh24h': 1.6e-07,
#   'priceLow24h': 1.4e-07},
#  {'name': 'XTZBEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000000.0,
#   'minProvideSize': 1000000.0,
#   'last': 1.3e-07,
#   'bid': 1.3e-07,
#   'ask': 1.5e-07,
#   'price': 1.3e-07,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -0.07142857142857142,
#   'change24h': -0.07142857142857142,
#   'changeBod': -0.07142857142857142,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 1.5e-07,
#   'priceLow24h': 1.3e-07},
#  {'name': 'XTZBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 1.752e-05,
#   'bid': 1.795e-05,
#   'ask': 1.962e-05,
#   'price': 1.795e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.06266318537859007,
#   'change24h': -0.03390742734122713,
#   'changeBod': -0.07712082262210797,
#   'quoteVolume24h': 622.7338,
#   'volumeUsd24h': 622.7338,
#   'priceHigh24h': 1.977e-05,
#   'priceLow24h': 1.736e-05},
#  {'name': 'XTZBULL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 1.919e-05,
#   'bid': 1.793e-05,
#   'ask': 1.963e-05,
#   'price': 1.919e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0031364349189754314,
#   'change24h': 0.031166039763567976,
#   'changeBod': 0.0,
#   'quoteVolume24h': 18.277,
#   'volumeUsd24h': 18.2751723,
#   'priceHigh24h': 1.919e-05,
#   'priceLow24h': 1.737e-05},
#  {'name': 'XTZHALF/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.25,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 6423.0,
#   'bid': 6190.5,
#   'ask': 6232.25,
#   'price': 6232.25,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZHALF',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.004270233251420054,
#   'change24h': 0.00784313725490196,
#   'changeBod': 0.0012852954171185284,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 6423.0,
#   'priceLow24h': 6112.75},
#  {'name': 'XTZHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 65.03,
#   'bid': 65.7,
#   'ask': 66.445,
#   'price': 65.7,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.00912450041475002,
#   'change24h': -0.016172506738544475,
#   'changeBod': -0.002277904328018223,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 68.265,
#   'priceLow24h': 65.03},
#  {'name': 'ZECBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 100.0,
#   'minProvideSize': 100.0,
#   'last': 0.003027,
#   'bid': 0.002984,
#   'ask': 0.003094,
#   'price': 0.003027,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ZECBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.003620803159973667,
#   'change24h': 0.031345826235093695,
#   'changeBod': 0.0,
#   'quoteVolume24h': 388.6043,
#   'volumeUsd24h': 388.6043,
#   'priceHigh24h': 0.003316,
#   'priceLow24h': 0.002877},
#  {'name': 'ZECBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 0.00015035,
#   'bid': 0.00015045,
#   'ask': 0.00015455,
#   'price': 0.00015045,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ZECBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0006651147322913202,
#   'change24h': -0.056739811912225706,
#   'changeBod': -0.016987912446912775,
#   'quoteVolume24h': 203.81105,
#   'volumeUsd24h': 203.81105,
#   'priceHigh24h': 0.00016275,
#   'priceLow24h': 0.00013395}]

# %%
df = pd.DataFrame(data)
df = df.set_index('name')
df
# Out:
#               enabled  postOnly  priceIncrement  sizeIncrement  \
# name
# 1INCH-PERP       True     False    1.000000e-04        1.00000
# 1INCH-0930       True     False    1.000000e-04        1.00000
# 1INCH-1230       True     False    1.000000e-04        1.00000
# 1INCH/USD        True     False    1.000000e-04        1.00000
# AAPL-0930        True     False    1.000000e-02        0.01000
# ...               ...       ...             ...            ...
# XTZBULL/USDT     True     False    1.000000e-08    10000.00000
# XTZHALF/USD      True     False    2.500000e-01        0.00001
# XTZHEDGE/USD     True     False    5.000000e-03        0.00100
# ZECBEAR/USD      True     False    1.000000e-06      100.00000
# ZECBULL/USD      True     False    5.000000e-08     1000.00000
#
#               minProvideSize         last          bid          ask  \
# name
# 1INCH-PERP           1.00000     0.589700     0.589600     0.589800
# 1INCH-0930           1.00000     0.589500     0.585900     0.588400
# 1INCH-1230           1.00000     0.572000     0.569000     0.571400
# 1INCH/USD            1.00000     0.590000     0.590200     0.590700
# AAPL-0930            0.01000   150.040000   149.230000   149.790000
# ...                      ...          ...          ...          ...
# XTZBULL/USDT     10000.00000     0.000019     0.000018     0.000020
# XTZHALF/USD          0.00001  6423.000000  6190.500000  6232.250000
# XTZHEDGE/USD         0.00100    65.030000    65.700000    66.445000
# ZECBEAR/USD        100.00000     0.003027     0.002984     0.003094
# ZECBULL/USD       1000.00000     0.000150     0.000150     0.000155
#
#                     price    type  ... highLeverageFeeExempt  \
# name                               ...
# 1INCH-PERP       0.589700  future  ...                 False
# 1INCH-0930       0.588400  future  ...                 False
# 1INCH-1230       0.571400  future  ...                 False
# 1INCH/USD        0.590200    spot  ...                  True
# AAPL-0930      149.790000  future  ...                 False
# ...                   ...     ...  ...                   ...
# XTZBULL/USDT     0.000019    spot  ...                  True
# XTZHALF/USD   6232.250000    spot  ...                  True
# XTZHEDGE/USD    65.700000    spot  ...                  True
# ZECBEAR/USD      0.003027    spot  ...                  True
# ZECBULL/USD      0.000150    spot  ...                  True
#
#              largeOrderThreshold  change1h change24h changeBod  \
# name
# 1INCH-PERP                 350.0  0.011145 -0.016511  0.004942
# 1INCH-0930                 350.0  0.012040 -0.009928  0.006500
# 1INCH-1230                 350.0  0.013480 -0.016185  0.010255
# 1INCH/USD                  280.0  0.010443 -0.016497  0.005109
# AAPL-0930                  350.0 -0.001666 -0.003990 -0.001666
# ...                          ...       ...       ...       ...
# XTZBULL/USDT               196.0  0.003136  0.031166  0.000000
# XTZHALF/USD                280.0  0.004270  0.007843  0.001285
# XTZHEDGE/USD               280.0 -0.009125 -0.016173 -0.002278
# ZECBEAR/USD                280.0 -0.003621  0.031346  0.000000
# ZECBULL/USD                280.0  0.000665 -0.056740 -0.016988
#
#               quoteVolume24h  volumeUsd24h  priceHigh24h  priceLow24h  \
# name
# 1INCH-PERP      3.980106e+06  3.980106e+06      0.600400     0.574400
# 1INCH-0930      9.113077e+03  9.113077e+03      0.595400     0.572000
# 1INCH-1230      1.349158e+04  1.349158e+04      0.582000     0.556400
# 1INCH/USD       1.550202e+06  1.550202e+06      0.601100     0.574500
# AAPL-0930       8.391964e+04  8.391964e+04    150.730000   145.130000
# ...                      ...           ...           ...          ...
# XTZBULL/USDT    1.827700e+01  1.827517e+01      0.000019     0.000017
# XTZHALF/USD     0.000000e+00  0.000000e+00   6423.000000  6112.750000
# XTZHEDGE/USD    0.000000e+00  0.000000e+00     68.265000    65.030000
# ZECBEAR/USD     3.886043e+02  3.886043e+02      0.003316     0.002877
# ZECBULL/USD     2.038110e+02  2.038110e+02      0.000163     0.000134
#
#               tokenizedEquity
# name
# 1INCH-PERP                NaN
# 1INCH-0930                NaN
# 1INCH-1230                NaN
# 1INCH/USD                 NaN
# AAPL-0930                True
# ...                       ...
# XTZBULL/USDT              NaN
# XTZHALF/USD               NaN
# XTZHEDGE/USD              NaN
# ZECBEAR/USD               NaN
# ZECBULL/USD               NaN
#
# [935 rows x 26 columns]

# %%
market_name = 'BTC/USD'
path = f'/markets/{market_name}'
url = api_url + path
url
# Out:
# 'https://ftx.com/api/markets/BTC/USD'

# %%
res = requests.get(url).json()
df = pd.DataFrame(res)['result']
df
# Out:
# ask                             19499.0
# baseCurrency                        BTC
# bid                             19498.0
# change1h                       0.003396
# change24h                      0.026479
# changeBod                      0.003035
# enabled                            True
# futureType                         None
# highLeverageFeeExempt              True
# isEtfMarket                       False
# largeOrderThreshold              2400.0
# last                            19499.0
# minProvideSize                   0.0001
# name                            BTC/USD
# postOnly                          False
# price                           19499.0
# priceHigh24h                    19767.0
# priceIncrement                      1.0
# priceLow24h                     18464.0
# quoteCurrency                       USD
# quoteVolume24h           889578152.9641
# restricted                        False
# sizeIncrement                    0.0001
# type                               spot
# underlying                         None
# volumeUsd24h             889578152.9641
# Name: result, dtype: object

# %%
resolution = 900
start_time = datetime.datetime(2022, 9, 28).timestamp()
path = f'/markets/{market_name}/candles?resolution={resolution}&start_time={start_time}'

# %%
url = api_url + path
res = requests.get(url).json()
df = pd.DataFrame(res['result'])
df
# Out:
#                     startTime          time     open     high      low  \
# 0   2022-09-28T05:00:00+00:00  1.664341e+12  18761.0  18773.0  18652.0
# 1   2022-09-28T05:15:00+00:00  1.664342e+12  18693.0  18765.0  18693.0
# 2   2022-09-28T05:30:00+00:00  1.664343e+12  18764.0  18809.0  18732.0
# 3   2022-09-28T05:45:00+00:00  1.664344e+12  18801.0  18832.0  18783.0
# 4   2022-09-28T06:00:00+00:00  1.664345e+12  18824.0  18883.0  18803.0
# ..                        ...           ...      ...      ...      ...
# 80  2022-09-29T01:00:00+00:00  1.664413e+12  19438.0  19466.0  19421.0
# 81  2022-09-29T01:15:00+00:00  1.664414e+12  19452.0  19521.0  19450.0
# 82  2022-09-29T01:30:00+00:00  1.664415e+12  19512.0  19596.0  19506.0
# 83  2022-09-29T01:45:00+00:00  1.664416e+12  19555.0  19574.0  19490.0
# 84  2022-09-29T02:00:00+00:00  1.664417e+12  19492.0  19500.0  19492.0
#
#       close        volume
# 0   18693.0  1.215158e+07
# 1   18764.0  5.305300e+06
# 2   18801.0  6.245727e+06
# 3   18823.0  2.841661e+06
# 4   18807.0  5.963039e+06
# ..      ...           ...
# 80  19452.0  2.786363e+06
# 81  19512.0  3.588505e+06
# 82  19555.0  4.603931e+06
# 83  19492.0  2.621898e+06
# 84  19492.0  9.032045e+04
#
# [85 rows x 7 columns]

# %%
df['date'] = pd.to_datetime(df['startTime'])
df = df.set_index('date')
df = df.drop(columns = ['startTime', 'time'])
df.head()
# Out:
#                              open    high     low   close        volume
# date
# 2022-02-02 00:00:00+00:00  2789.1  3286.5  2301.1  2948.6  1.296256e+10
# 2022-03-03 00:00:00+00:00  2948.7  3483.7  2444.7  3456.4  1.074473e+10
# 2022-04-02 00:00:00+00:00  3456.4  3581.4  2714.5  2824.4  9.239965e+09
# 2022-05-02 00:00:00+00:00  2824.4  2966.5  1700.0  1940.3  1.633315e+10
# 2022-06-01 00:00:00+00:00  1940.3  1971.5   880.0  1070.4  1.655756e+10
