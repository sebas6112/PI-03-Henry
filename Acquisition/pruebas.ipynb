# %%
import datetime
import requests
import pandas as pd
# from client import FtxClient
# from local_settings import ftxus as settings

# %%
api_url = 'https://ftx.com/api'
api = "/markets"
url = api_url + api
url
# Out:
# 'https://ftx.com/api/markets'

# %%
markets = requests.get(url).json()
data = markets['result']
data
# Out:
# [{'name': '1INCH-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.6086,
#   'bid': 0.6085,
#   'ask': 0.6086,
#   'price': 0.6086,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': '1INCH',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0059504132231404955,
#   'change24h': -0.01996779388083736,
#   'changeBod': -0.023740776387552134,
#   'quoteVolume24h': 6046160.8327,
#   'volumeUsd24h': 6046160.8327,
#   'priceHigh24h': 0.6485,
#   'priceLow24h': 0.6013},
#  {'name': '1INCH-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.6038,
#   'bid': 0.6036,
#   'ask': 0.6062,
#   'price': 0.6038,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': '1INCH',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0,
#   'change24h': -0.022819226412040785,
#   'changeBod': -0.025971930956605903,
#   'quoteVolume24h': 7966.0942,
#   'volumeUsd24h': 7966.0942,
#   'priceHigh24h': 0.6448,
#   'priceLow24h': 0.5985},
#  {'name': '1INCH-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.5901,
#   'bid': 0.5873,
#   'ask': 0.5903,
#   'price': 0.5901,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': '1INCH',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.008028698325930988,
#   'change24h': -0.02041832669322709,
#   'changeBod': -0.02414420373739044,
#   'quoteVolume24h': 1065.1072,
#   'volumeUsd24h': 1065.1072,
#   'priceHigh24h': 0.6258,
#   'priceLow24h': 0.5829},
#  {'name': '1INCH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.6093,
#   'bid': 0.6088,
#   'ask': 0.6093,
#   'price': 0.6093,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': '1INCH',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.005943536404160475,
#   'change24h': -0.01884057971014493,
#   'changeBod': -0.023557692307692307,
#   'quoteVolume24h': 1466166.8916,
#   'volumeUsd24h': 1466166.8916,
#   'priceHigh24h': 0.6482,
#   'priceLow24h': 0.6013},
#  {'name': 'AAPL-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 152.0,
#   'bid': 151.92,
#   'ask': 152.59,
#   'price': 152.0,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAPL',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0,
#   'change24h': 0.0048258081575989955,
#   'changeBod': 0.0048258081575989955,
#   'quoteVolume24h': 15625.9499,
#   'volumeUsd24h': 15625.9499,
#   'priceHigh24h': 154.69,
#   'priceLow24h': 150.24},
#  {'name': 'AAPL-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 151.89,
#   'bid': 151.86,
#   'ask': 152.44,
#   'price': 151.89,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAPL',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0011864741941862765,
#   'change24h': 0.007228116710875331,
#   'changeBod': 0.005095288512440445,
#   'quoteVolume24h': 49681.0337,
#   'volumeUsd24h': 49681.0337,
#   'priceHigh24h': 154.58,
#   'priceLow24h': 149.67},
#  {'name': 'AAPL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 152.23,
#   'bid': 152.23,
#   'ask': 152.47,
#   'price': 152.23,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAPL',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0010521470375484973,
#   'change24h': 0.0067455856094173665,
#   'changeBod': 0.006545887331393811,
#   'quoteVolume24h': 152735.8161,
#   'volumeUsd24h': 152735.8161,
#   'priceHigh24h': 154.71,
#   'priceLow24h': 150.28},
#  {'name': 'AAVE-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 76.92,
#   'bid': 76.91,
#   'ask': 76.92,
#   'price': 76.92,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAVE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.008522354792185657,
#   'change24h': 0.013705851344227728,
#   'changeBod': 0.010111621799080761,
#   'quoteVolume24h': 17897990.3421,
#   'volumeUsd24h': 17897990.3421,
#   'priceHigh24h': 80.98,
#   'priceLow24h': 74.56},
#  {'name': 'AAVE-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 78.39,
#   'bid': 76.7,
#   'ask': 77.32,
#   'price': 77.32,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAVE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.007820646506777894,
#   'change24h': 0.017368421052631578,
#   'changeBod': 0.016031537450722732,
#   'quoteVolume24h': 5430.8497,
#   'volumeUsd24h': 5430.8497,
#   'priceHigh24h': 80.83,
#   'priceLow24h': 75.1},
#  {'name': 'AAVE-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 76.22,
#   'bid': 75.75,
#   'ask': 76.43,
#   'price': 76.22,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAVE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.013159643759138641,
#   'change24h': 0.012621230237810548,
#   'changeBod': 0.009670154987415552,
#   'quoteVolume24h': 3319.2569,
#   'volumeUsd24h': 3319.2569,
#   'priceHigh24h': 80.16,
#   'priceLow24h': 74.44},
#  {'name': 'AAVE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 76.89,
#   'bid': 76.86,
#   'ask': 76.88,
#   'price': 76.88,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': 0.007733647922401363,
#   'change24h': 0.013045196995651601,
#   'changeBod': 0.010116936013664432,
#   'quoteVolume24h': 1928234.6106,
#   'volumeUsd24h': 1928234.6106,
#   'priceHigh24h': 81.01,
#   'priceLow24h': 74.55},
#  {'name': 'AAVE/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 76.92,
#   'bid': 76.82,
#   'ask': 76.93,
#   'price': 76.92,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': 0.008125819134993446,
#   'change24h': 0.013038324772817068,
#   'changeBod': 0.009846396218983852,
#   'quoteVolume24h': 79791.6843,
#   'volumeUsd24h': 79783.70513157,
#   'priceHigh24h': 81.0,
#   'priceLow24h': 74.62},
#  {'name': 'ABNB-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.025,
#   'minProvideSize': 0.025,
#   'last': 105.18,
#   'bid': 106.595,
#   'ask': 107.135,
#   'price': 106.595,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ABNB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.003530408585953681,
#   'change24h': 0.024016523368077237,
#   'changeBod': 0.024804114791135895,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 108.3,
#   'priceLow24h': 103.86},
#  {'name': 'ABNB-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.025,
#   'minProvideSize': 0.025,
#   'last': 110.24,
#   'bid': 106.69,
#   'ask': 107.105,
#   'price': 107.105,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ABNB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.0009793862512825296,
#   'change24h': 0.030450259765249184,
#   'changeBod': 0.02995480334647562,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 108.805,
#   'priceLow24h': 103.82},
#  {'name': 'ABNB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.025,
#   'minProvideSize': 0.025,
#   'last': 106.535,
#   'bid': 106.58,
#   'ask': 106.975,
#   'price': 106.58,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ABNB',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.00042239639555075796,
#   'change24h': 0.026535034914519626,
#   'changeBod': 0.026535034914519626,
#   'quoteVolume24h': 131.912625,
#   'volumeUsd24h': 131.912625,
#   'priceHigh24h': 108.22,
#   'priceLow24h': 103.56},
#  {'name': 'ACB-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.206,
#   'bid': 1.21,
#   'ask': 1.228,
#   'price': 1.21,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ACB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.003316749585406302,
#   'change24h': 0.033304867634500426,
#   'changeBod': 0.03418803418803419,
#   'quoteVolume24h': 6112.2407,
#   'volumeUsd24h': 6112.2407,
#   'priceHigh24h': 1.237,
#   'priceLow24h': 1.168},
#  {'name': 'ACB-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.25,
#   'bid': 1.15,
#   'ask': 1.287,
#   'price': 1.25,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ACB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0,
#   'change24h': 0.012145748987854251,
#   'changeBod': 0.012145748987854251,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 1.25,
#   'priceLow24h': 1.168},
#  {'name': 'ACB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.189,
#   'bid': 1.217,
#   'ask': 1.228,
#   'price': 1.217,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ACB',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.011637572734829594,
#   'change24h': 0.032230703986429174,
#   'changeBod': 0.040170940170940174,
#   'quoteVolume24h': 554.0528,
#   'volumeUsd24h': 554.0528,
#   'priceHigh24h': 1.244,
#   'priceLow24h': 1.17},
#  {'name': 'ADA-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.44117,
#   'bid': 0.44119,
#   'ask': 0.441215,
#   'price': 0.44119,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ADA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.0012822695035460993,
#   'change24h': -0.009363211783725525,
#   'changeBod': -0.012467544095263676,
#   'quoteVolume24h': 47949571.31263,
#   'volumeUsd24h': 47949571.31263,
#   'priceHigh24h': 0.4633,
#   'priceLow24h': 0.43688},
#  {'name': 'ADA-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.440435,
#   'bid': 0.440075,
#   'ask': 0.440465,
#   'price': 0.440435,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ADA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.00237829718473338,
#   'change24h': -0.008576348636450607,
#   'changeBod': -0.011191684253064523,
#   'quoteVolume24h': 814971.742875,
#   'volumeUsd24h': 814971.742875,
#   'priceHigh24h': 0.46191,
#   'priceLow24h': 0.43616},
#  {'name': 'ADA-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.43067,
#   'bid': 0.43136,
#   'ask': 0.432525,
#   'price': 0.43136,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ADA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.002754692857557971,
#   'change24h': -0.011254498361106655,
#   'changeBod': -0.013154583514447165,
#   'quoteVolume24h': 32825.82775,
#   'volumeUsd24h': 32825.82775,
#   'priceHigh24h': 0.45239,
#   'priceLow24h': 0.427425},
#  {'name': 'AGLD-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.318,
#   'bid': 0.318,
#   'ask': 0.3185,
#   'price': 0.318,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AGLD',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.0015698587127158557,
#   'change24h': -0.02304147465437788,
#   'changeBod': -0.024539877300613498,
#   'quoteVolume24h': 1755016.2659,
#   'volumeUsd24h': 1755016.2659,
#   'priceHigh24h': 0.338,
#   'priceLow24h': 0.313},
#  {'name': 'AGLD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.318,
#   'bid': 0.318,
#   'ask': 0.3195,
#   'price': 0.318,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AGLD',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.004694835680751174,
#   'change24h': -0.018518518518518517,
#   'changeBod': -0.026033690658499236,
#   'quoteVolume24h': 16958.04515,
#   'volumeUsd24h': 16958.04515,
#   'priceHigh24h': 0.3415,
#   'priceLow24h': 0.314},
#  {'name': 'AKRO/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.003905,
#   'bid': 0.00391,
#   'ask': 0.003935,
#   'price': 0.00391,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AKRO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0012804097311139564,
#   'change24h': -0.020050125313283207,
#   'changeBod': -0.0225,
#   'quoteVolume24h': 2009.82904,
#   'volumeUsd24h': 2009.82904,
#   'priceHigh24h': 0.00411,
#   'priceLow24h': 0.003905},
#  {'name': 'AKRO/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.003925,
#   'bid': 0.00391,
#   'ask': 0.003925,
#   'price': 0.003925,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AKRO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': -0.015056461731493099,
#   'changeBod': -0.015056461731493099,
#   'quoteVolume24h': 942.66405,
#   'volumeUsd24h': 942.569783595,
#   'priceHigh24h': 0.00409,
#   'priceLow24h': 0.00391},
#  {'name': 'ALCX-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 20.2,
#   'bid': 20.2,
#   'ask': 20.3,
#   'price': 20.2,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALCX',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.01,
#   'change24h': 0.01,
#   'changeBod': 0.0,
#   'quoteVolume24h': 395005.6643,
#   'volumeUsd24h': 395005.6643,
#   'priceHigh24h': 21.9,
#   'priceLow24h': 19.9},
#  {'name': 'ALCX/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 20.1,
#   'bid': 20.1,
#   'ask': 20.2,
#   'price': 20.1,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALCX',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.0049504950495049506,
#   'changeBod': -0.0049504950495049506,
#   'quoteVolume24h': 27707.4615,
#   'volumeUsd24h': 27707.4615,
#   'priceHigh24h': 21.9,
#   'priceLow24h': 20.0},
#  {'name': 'ALEPH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.11765,
#   'bid': 0.1176,
#   'ask': 0.11795,
#   'price': 0.11765,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALEPH',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0021204410517387615,
#   'change24h': -0.0016970725498515061,
#   'changeBod': -0.0008492569002123143,
#   'quoteVolume24h': 21845.27765,
#   'volumeUsd24h': 21845.27765,
#   'priceHigh24h': 0.1198,
#   'priceLow24h': 0.1165},
#  {'name': 'ALGO-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3526,
#   'bid': 0.3526,
#   'ask': 0.3527,
#   'price': 0.3526,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALGO',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.010315186246418338,
#   'change24h': -0.03529411764705882,
#   'changeBod': -0.03766375545851528,
#   'quoteVolume24h': 35947620.8054,
#   'volumeUsd24h': 35947620.8054,
#   'priceHigh24h': 0.3753,
#   'priceLow24h': 0.3371},
#  {'name': 'ALGO-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3523,
#   'bid': 0.3523,
#   'ask': 0.3548,
#   'price': 0.3523,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALGO',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.011194029850746268,
#   'change24h': -0.03795740032768979,
#   'changeBod': -0.041360544217687076,
#   'quoteVolume24h': 29625.7333,
#   'volumeUsd24h': 29625.7333,
#   'priceHigh24h': 0.3757,
#   'priceLow24h': 0.338},
#  {'name': 'ALGO-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3525,
#   'bid': 0.3537,
#   'ask': 0.3563,
#   'price': 0.3537,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALGO',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.009417808219178082,
#   'change24h': -0.03938077131993482,
#   'changeBod': -0.037026953444051186,
#   'quoteVolume24h': 34314.3424,
#   'volumeUsd24h': 34314.3424,
#   'priceHigh24h': 0.3788,
#   'priceLow24h': 0.3414},
#  {'name': 'ALGO/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3517,
#   'bid': 0.3526,
#   'ask': 0.353,
#   'price': 0.3526,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': 0.010025780578630765,
#   'change24h': -0.03503010399562124,
#   'changeBod': -0.038188761593016915,
#   'quoteVolume24h': 695412.372,
#   'volumeUsd24h': 695412.372,
#   'priceHigh24h': 0.3752,
#   'priceLow24h': 0.3375},
#  {'name': 'ALGO/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.352,
#   'bid': 0.3527,
#   'ask': 0.3531,
#   'price': 0.3527,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': 0.009733753220727169,
#   'change24h': -0.03449219819326581,
#   'changeBod': -0.03817834742296155,
#   'quoteVolume24h': 37316.9537,
#   'volumeUsd24h': 37313.22200463,
#   'priceHigh24h': 0.3749,
#   'priceLow24h': 0.3376},
#  {'name': 'ALICE-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.6875,
#   'bid': 1.6875,
#   'ask': 1.69,
#   'price': 1.6875,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALICE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.004464285714285714,
#   'change24h': -0.01171303074670571,
#   'changeBod': -0.016034985422740525,
#   'quoteVolume24h': 1276203.0025,
#   'volumeUsd24h': 1276203.0025,
#   'priceHigh24h': 1.7875,
#   'priceLow24h': 1.6625},
#  {'name': 'ALICE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.6875,
#   'bid': 1.685,
#   'ask': 1.69,
#   'price': 1.6875,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALICE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.004464285714285714,
#   'change24h': -0.014598540145985401,
#   'changeBod': -0.014598540145985401,
#   'quoteVolume24h': 6676.289,
#   'volumeUsd24h': 6676.289,
#   'priceHigh24h': 1.785,
#   'priceLow24h': 1.6675},
#  {'name': 'ALPHA-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.1075,
#   'bid': 0.1075,
#   'ask': 0.1076,
#   'price': 0.1075,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALPHA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.005612722170252572,
#   'change24h': 0.02478551000953289,
#   'changeBod': 0.02478551000953289,
#   'quoteVolume24h': 1608046.84095,
#   'volumeUsd24h': 1608046.84095,
#   'priceHigh24h': 0.112,
#   'priceLow24h': 0.1049},
#  {'name': 'ALPHA/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.1075,
#   'bid': 0.10735,
#   'ask': 0.1075,
#   'price': 0.1075,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALPHA',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.006554307116104869,
#   'change24h': 0.025274201239866477,
#   'changeBod': 0.02478551000953289,
#   'quoteVolume24h': 251253.38965,
#   'volumeUsd24h': 251253.38965,
#   'priceHigh24h': 0.11195,
#   'priceLow24h': 0.10485},
#  {'name': 'ALT-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.05,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1838.75,
#   'bid': 1839.95,
#   'ask': 1841.2,
#   'price': 1839.95,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALT',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 600.0,
#   'change1h': 0.004641131344017036,
#   'change24h': -0.00942151874882231,
#   'changeBod': -0.012505031530927144,
#   'quoteVolume24h': 3693451.86935,
#   'volumeUsd24h': 3693451.86935,
#   'priceHigh24h': 1932.15,
#   'priceLow24h': 1810.0},
#  {'name': 'ALT-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.05,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1830.75,
#   'bid': 1833.05,
#   'ask': 1837.95,
#   'price': 1833.05,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALT',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 600.0,
#   'change1h': 0.006092373555805593,
#   'change24h': -0.012232251111410481,
#   'changeBod': -0.013481513373876541,
#   'quoteVolume24h': 59459.44125,
#   'volumeUsd24h': 59459.44125,
#   'priceHigh24h': 1931.7,
#   'priceLow24h': 1807.65},
#  {'name': 'ALT-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.05,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1803.55,
#   'bid': 1803.8,
#   'ask': 1806.6,
#   'price': 1803.8,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALT',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 600.0,
#   'change1h': 0.004370945739023915,
#   'change24h': -0.013831939205073534,
#   'changeBod': -0.013993659123209795,
#   'quoteVolume24h': 8723.7858,
#   'volumeUsd24h': 8723.7858,
#   'priceHigh24h': 1897.25,
#   'priceLow24h': 1775.3},
#  {'name': 'AMC-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 13.24,
#   'bid': 13.275,
#   'ask': 13.7125,
#   'price': 13.275,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMC',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.00018828845791752966,
#   'change24h': 0.040156709108716944,
#   'changeBod': 0.041176470588235294,
#   'quoteVolume24h': 15567.79025,
#   'volumeUsd24h': 15567.79025,
#   'priceHigh24h': 13.7325,
#   'priceLow24h': 12.725},
#  {'name': 'AMC-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 7.425,
#   'bid': 7.3975,
#   'ask': 7.4925,
#   'price': 7.425,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMC',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0,
#   'change24h': 0.06949945984875765,
#   'changeBod': 0.06911447084233262,
#   'quoteVolume24h': 3857.6875,
#   'volumeUsd24h': 3857.6875,
#   'priceHigh24h': 7.5275,
#   'priceLow24h': 6.9425},
#  {'name': 'AMC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 7.3975,
#   'bid': 7.42,
#   'ask': 7.49,
#   'price': 7.42,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMC',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.003041568097330179,
#   'change24h': 0.07731397459165154,
#   'changeBod': 0.06379928315412187,
#   'quoteVolume24h': 9452.61575,
#   'volumeUsd24h': 9452.61575,
#   'priceHigh24h': 7.535,
#   'priceLow24h': 6.8875},
#  {'name': 'AMD-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 66.7,
#   'bid': 67.39,
#   'ask': 67.69,
#   'price': 67.39,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMD',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.002976633427593392,
#   'change24h': 0.011709953460441375,
#   'changeBod': 0.007927011666168113,
#   'quoteVolume24h': 272.3288,
#   'volumeUsd24h': 272.3288,
#   'priceHigh24h': 68.85,
#   'priceLow24h': 66.2},
#  {'name': 'AMD-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 66.23,
#   'bid': 67.43,
#   'ask': 67.69,
#   'price': 67.43,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMD',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0026765799256505576,
#   'change24h': 0.012462462462462463,
#   'changeBod': 0.009129003292427417,
#   'quoteVolume24h': 3738.7,
#   'volumeUsd24h': 3738.7,
#   'priceHigh24h': 68.88,
#   'priceLow24h': 66.23},
#  {'name': 'AMD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 67.22,
#   'bid': 67.33,
#   'ask': 67.64,
#   'price': 67.33,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMD',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.00044576523031203565,
#   'change24h': 0.01630188679245283,
#   'changeBod': 0.01431153962036758,
#   'quoteVolume24h': 325.0806,
#   'volumeUsd24h': 325.0806,
#   'priceHigh24h': 68.81,
#   'priceLow24h': 66.11},
#  {'name': 'AMPL-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 1.1053,
#   'bid': 1.1073,
#   'ask': 1.108,
#   'price': 1.1073,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMPL',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.011787280701754386,
#   'change24h': -0.041962277210590065,
#   'changeBod': -0.043947504748748055,
#   'quoteVolume24h': 357040.227,
#   'volumeUsd24h': 357040.227,
#   'priceHigh24h': 1.1854,
#   'priceLow24h': 1.0511},
#  {'name': 'AMPL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 1.1044,
#   'bid': 1.1044,
#   'ask': 1.1069,
#   'price': 1.1044,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMPL',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.009321878998354963,
#   'change24h': -0.053398474329304876,
#   'changeBod': -0.05534171584979899,
#   'quoteVolume24h': 170703.3744,
#   'volumeUsd24h': 170703.3744,
#   'priceHigh24h': 1.1974,
#   'priceLow24h': 1.0606},
#  {'name': 'AMPL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 1.1089,
#   'bid': 1.1043,
#   'ask': 1.1068,
#   'price': 1.1068,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMPL',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.009393524851801185,
#   'change24h': -0.04971237228470851,
#   'changeBod': -0.05052757999485288,
#   'quoteVolume24h': 40988.8264,
#   'volumeUsd24h': 40984.72751736,
#   'priceHigh24h': 1.1935,
#   'priceLow24h': 1.0615},
#  {'name': 'AMZN-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 115.0,
#   'bid': 114.0,
#   'ask': 114.7,
#   'price': 114.7,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMZN',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.0017406440382941688,
#   'change24h': -0.006926406926406926,
#   'changeBod': -0.006065857885615251,
#   'quoteVolume24h': 9343.35,
#   'volumeUsd24h': 9343.35,
#   'priceHigh24h': 117.7,
#   'priceLow24h': 112.9},
#  {'name': 'AMZN-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 113.9,
#   'bid': 114.1,
#   'ask': 114.6,
#   'price': 114.1,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMZN',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.001755926251097454,
#   'change24h': -0.0052310374891020054,
#   'changeBod': -0.0052310374891020054,
#   'quoteVolume24h': 660.915,
#   'volumeUsd24h': 660.915,
#   'priceHigh24h': 117.6,
#   'priceLow24h': 112.3},
#  {'name': 'AMZN/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 114.4,
#   'bid': 114.2,
#   'ask': 114.5,
#   'price': 114.4,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMZN',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.0026155187445510027,
#   'changeBod': -0.004351610095735422,
#   'quoteVolume24h': 29555.14,
#   'volumeUsd24h': 29555.14,
#   'priceHigh24h': 117.9,
#   'priceLow24h': 112.8},
#  {'name': 'APE-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.4375,
#   'bid': 5.435,
#   'ask': 5.4375,
#   'price': 5.4375,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'APE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.008344923504867872,
#   'change24h': -0.010374010374010374,
#   'changeBod': -0.011273752159287208,
#   'quoteVolume24h': 44695577.891,
#   'volumeUsd24h': 44695577.891,
#   'priceHigh24h': 5.797,
#   'priceLow24h': 5.288},
#  {'name': 'APE-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.3365,
#   'bid': 5.4175,
#   'ask': 5.44,
#   'price': 5.4175,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'APE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.007719494047619048,
#   'change24h': -0.009959795321637427,
#   'changeBod': -0.011495301523583615,
#   'quoteVolume24h': 3973.2791,
#   'volumeUsd24h': 3973.2791,
#   'priceHigh24h': 5.781,
#   'priceLow24h': 5.2915},
#  {'name': 'APE-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.303,
#   'bid': 5.2955,
#   'ask': 5.32,
#   'price': 5.303,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'APE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.004546315590073877,
#   'change24h': -0.012200800968613206,
#   'changeBod': -0.012200800968613206,
#   'quoteVolume24h': 2983.9161,
#   'volumeUsd24h': 2983.9161,
#   'priceHigh24h': 5.6465,
#   'priceLow24h': 5.1775},
#  {'name': 'APE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.437,
#   'bid': 5.436,
#   'ask': 5.4375,
#   'price': 5.437,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'APE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.00815872427220471,
#   'change24h': -0.010555050045495906,
#   'changeBod': -0.011094943615860314,
#   'quoteVolume24h': 5412493.7627,
#   'volumeUsd24h': 5412493.7627,
#   'priceHigh24h': 5.797,
#   'priceLow24h': 5.289},
#  {'name': 'APEAMC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 3.5175,
#   'bid': 3.365,
#   'ask': 3.435,
#   'price': 3.435,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'APEAMC',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.007942238267148015,
#   'change24h': -0.005788712011577424,
#   'changeBod': -0.041172365666434056,
#   'quoteVolume24h': 455.01,
#   'volumeUsd24h': 455.01,
#   'priceHigh24h': 3.7575,
#   'priceLow24h': 3.37},
#  {'name': 'APHA/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 2.417,
#   'bid': 2.356,
#   'ask': 2.365,
#   'price': 2.365,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'APHA',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0038200339558573855,
#   'change24h': 0.04185022026431718,
#   'changeBod': 0.04001759014951627,
#   'quoteVolume24h': 3.6255,
#   'volumeUsd24h': 3.6255,
#   'priceHigh24h': 2.419,
#   'priceLow24h': 2.27},
#  {'name': 'AR-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 9.442,
#   'bid': 9.436,
#   'ask': 9.444,
#   'price': 9.442,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AR',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.008222103577148959,
#   'change24h': 0.005216650697327798,
#   'changeBod': 0.0011663662389990457,
#   'quoteVolume24h': 2817210.594,
#   'volumeUsd24h': 2817210.594,
#   'priceHigh24h': 10.106,
#   'priceLow24h': 9.226},
#  {'name': 'ARKK-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 38.87,
#   'bid': 38.37,
#   'ask': 38.56,
#   'price': 38.56,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ARKK',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0,
#   'change24h': 0.026897470039946737,
#   'changeBod': 0.02553191489361702,
#   'quoteVolume24h': 54891.7778,
#   'volumeUsd24h': 54891.7778,
#   'priceHigh24h': 39.33,
#   'priceLow24h': 37.55},
#  {'name': 'ARKK-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 38.92,
#   'bid': 38.39,
#   'ask': 38.56,
#   'price': 38.56,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ARKK',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.0007774034724021767,
#   'change24h': 0.026350811817939846,
#   'changeBod': 0.024442082890541977,
#   'quoteVolume24h': 23047.1315,
#   'volumeUsd24h': 23047.1315,
#   'priceHigh24h': 39.35,
#   'priceLow24h': 37.41},
#  {'name': 'ARKK/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 38.5,
#   'bid': 38.32,
#   'ask': 38.5,
#   'price': 38.5,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ARKK',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0013003901170351106,
#   'change24h': 0.02529960053262317,
#   'changeBod': 0.02040816326530612,
#   'quoteVolume24h': 16996.0955,
#   'volumeUsd24h': 16996.0955,
#   'priceHigh24h': 39.32,
#   'priceLow24h': 37.45},
#  {'name': 'ASD-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.10568,
#   'bid': 0.10538,
#   'ask': 0.10568,
#   'price': 0.10568,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ASD',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0007575757575757576,
#   'change24h': -0.009188074254640915,
#   'changeBod': -0.00900225056264066,
#   'quoteVolume24h': 86961.996652,
#   'volumeUsd24h': 86961.996652,
#   'priceHigh24h': 0.1078,
#   'priceLow24h': 0.10442},
#  {'name': 'ASD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.10576,
#   'bid': 0.10577,
#   'ask': 0.10585,
#   'price': 0.10577,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ASD',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 9.455370650529501e-05,
#   'change24h': -0.007786116322701688,
#   'changeBod': -0.007972237854061152,
#   'quoteVolume24h': 28476.370653,
#   'volumeUsd24h': 28476.370653,
#   'priceHigh24h': 0.10767,
#   'priceLow24h': 0.10486},
#  {'name': 'ATLAS-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.00445425,
#   'bid': 0.0044545,
#   'ask': 0.00445525,
#   'price': 0.0044545,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATLAS',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.003039855888313443,
#   'change24h': -0.016340951750027602,
#   'changeBod': -0.015199248328082685,
#   'quoteVolume24h': 119086.6478525,
#   'volumeUsd24h': 119086.6478525,
#   'priceHigh24h': 0.0046255,
#   'priceLow24h': 0.00439775},
#  {'name': 'ATLAS/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.00444675,
#   'bid': 0.00444675,
#   'ask': 0.00445675,
#   'price': 0.00444675,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ATLAS',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.004347826086956522,
#   'change24h': -0.016966950370288492,
#   'changeBod': -0.01902713434811383,
#   'quoteVolume24h': 120595.1175125,
#   'volumeUsd24h': 120595.1175125,
#   'priceHigh24h': 0.00470575,
#   'priceLow24h': 0.0044},
#  {'name': 'ATOM-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 13.511,
#   'bid': 13.511,
#   'ask': 13.5115,
#   'price': 13.511,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATOM',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.006968511272591764,
#   'change24h': -0.026970580821720498,
#   'changeBod': -0.021934269581583902,
#   'quoteVolume24h': 154966321.76566,
#   'volumeUsd24h': 154966321.76566,
#   'priceHigh24h': 14.738,
#   'priceLow24h': 13.1135},
#  {'name': 'ATOM-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 13.427,
#   'bid': 13.4405,
#   'ask': 13.483,
#   'price': 13.4405,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATOM',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.004634301304331577,
#   'change24h': -0.026156577183639458,
#   'changeBod': -0.02587425258198949,
#   'quoteVolume24h': 39381.389655,
#   'volumeUsd24h': 39381.389655,
#   'priceHigh24h': 14.68,
#   'priceLow24h': 13.1515},
#  {'name': 'ATOM-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 13.1335,
#   'bid': 13.1045,
#   'ask': 13.1575,
#   'price': 13.1335,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATOM',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': 0.006629876599984671,
#   'change24h': -0.027544333789937432,
#   'changeBod': -0.023821911699122938,
#   'quoteVolume24h': 511651.085545,
#   'volumeUsd24h': 511651.085545,
#   'priceHigh24h': 14.3325,
#   'priceLow24h': 12.781},
#  {'name': 'ATOM/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 13.4975,
#   'bid': 13.5225,
#   'ask': 13.525,
#   'price': 13.5225,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ATOM',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.007450176941702366,
#   'change24h': -0.026457883369330453,
#   'changeBod': -0.02170374389582203,
#   'quoteVolume24h': 12983444.11525,
#   'volumeUsd24h': 12983444.11525,
#   'priceHigh24h': 14.74,
#   'priceLow24h': 13.135},
#  {'name': 'ATOM/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 13.5125,
#   'bid': 13.5175,
#   'ask': 13.5275,
#   'price': 13.5175,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ATOM',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': 0.007077668094617247,
#   'change24h': -0.026992981824725572,
#   'changeBod': -0.02277245617205856,
#   'quoteVolume24h': 619371.1615,
#   'volumeUsd24h': 619309.22438385,
#   'priceHigh24h': 14.7325,
#   'priceLow24h': 13.1625},
#  {'name': 'AUDIO-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.2145,
#   'bid': 0.214,
#   'ask': 0.2145,
#   'price': 0.2145,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
# ...
#   'priceHigh24h': 1.7e-06,
#   'priceLow24h': 1.39e-06},
#  {'name': 'VETBEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 100000.0,
#   'minProvideSize': 100000.0,
#   'last': 1.63e-06,
#   'bid': 1.64e-06,
#   'ask': 1.67e-06,
#   'price': 1.64e-06,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -0.012048192771084338,
#   'change24h': -0.029585798816568046,
#   'changeBod': -0.017964071856287425,
#   'quoteVolume24h': 1035.69,
#   'volumeUsd24h': 1035.586431,
#   'priceHigh24h': 1.7e-06,
#   'priceLow24h': 1.39e-06},
#  {'name': 'VETBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 8.481e-05,
#   'bid': 8.469e-05,
#   'ask': 8.532e-05,
#   'price': 8.481e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.004025097667811057,
#   'change24h': 0.0018901358535144714,
#   'changeBod': -0.0005892057506481263,
#   'quoteVolume24h': 7747.9661,
#   'volumeUsd24h': 7747.9661,
#   'priceHigh24h': 9.922e-05,
#   'priceLow24h': 8.255e-05},
#  {'name': 'VETBULL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 8.601e-05,
#   'bid': 8.464e-05,
#   'ask': 8.596e-05,
#   'price': 8.596e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.015715467328370553,
#   'change24h': 0.022481265611990008,
#   'changeBod': 0.015955560808415082,
#   'quoteVolume24h': 10312.32692,
#   'volumeUsd24h': 10311.295687308,
#   'priceHigh24h': 0.00010078,
#   'priceLow24h': 8.278e-05},
#  {'name': 'VETHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 100.5,
#   'bid': 99.5,
#   'ask': 100.5,
#   'price': 100.5,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 100.5,
#   'priceLow24h': 95.0},
#  {'name': 'XAUTBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 5782.5,
#   'bid': 5800.0,
#   'ask': 5907.5,
#   'price': 5800.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0030263726761781237,
#   'change24h': -0.007698887938408896,
#   'changeBod': -0.014024649383765405,
#   'quoteVolume24h': 505.748025,
#   'volumeUsd24h': 505.748025,
#   'priceHigh24h': 5920.0,
#   'priceLow24h': 5747.5},
#  {'name': 'XAUTBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 4527.0,
#   'bid': 4489.0,
#   'ask': 4567.0,
#   'price': 4527.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': 0.011168192986374805,
#   'changeBod': 0.007791629563668744,
#   'quoteVolume24h': 0.27167,
#   'volumeUsd24h': 0.27167,
#   'priceHigh24h': 4611.0,
#   'priceLow24h': 4447.0},
#  {'name': 'XAUTHALF/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.25,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 5657.25,
#   'bid': 5606.0,
#   'ask': 5630.25,
#   'price': 5630.25,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTHALF',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -4.440103010389841e-05,
#   'change24h': 0.0010668089078543807,
#   'changeBod': 0.00084436938938761,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 5657.25,
#   'priceLow24h': 5621.75},
#  {'name': 'XAUTHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 4926.5,
#   'bid': 4960.0,
#   'ask': 4995.0,
#   'price': 4960.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0003025108399717657,
#   'change24h': -0.002212834439750553,
#   'changeBod': -0.0011076427348706071,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 4974.0,
#   'priceLow24h': 4926.5},
#  {'name': 'XLMBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.009425,
#   'bid': 0.00981,
#   'ask': 0.009965,
#   'price': 0.00981,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XLMBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.007838179519595449,
#   'change24h': 0.07595283794899918,
#   'changeBod': 0.07595283794899918,
#   'quoteVolume24h': 1.60225,
#   'volumeUsd24h': 1.60225,
#   'priceHigh24h': 0.0100825,
#   'priceLow24h': 0.0084375},
#  {'name': 'XLMBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-07,
#   'sizeIncrement': 100.0,
#   'minProvideSize': 100.0,
#   'last': 0.0021285,
#   'bid': 0.002128,
#   'ask': 0.0021585,
#   'price': 0.0021285,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XLMBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.07976653696498054,
#   'changeBod': -0.08115691776386791,
#   'quoteVolume24h': 52807.78995,
#   'volumeUsd24h': 52807.78995,
#   'priceHigh24h': 0.002508,
#   'priceLow24h': 0.002081},
#  {'name': 'XRPBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000000.0,
#   'minProvideSize': 10000000.0,
#   'last': 5e-08,
#   'bid': 5e-08,
#   'ask': 7e-08,
#   'price': 5e-08,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 5e-08,
#   'priceLow24h': 5e-08},
#  {'name': 'XRPBEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000000.0,
#   'minProvideSize': 10000000.0,
#   'last': 9e-08,
#   'bid': 5e-08,
#   'ask': 1.7e-07,
#   'price': 9e-08,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 9e-08,
#   'priceLow24h': 9e-08},
#  {'name': 'XRPBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 3.127e-05,
#   'bid': 3.118e-05,
#   'ask': 3.127e-05,
#   'price': 3.127e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.03406084656084656,
#   'change24h': -0.12359865470852018,
#   'changeBod': -0.10272596843615495,
#   'quoteVolume24h': 197828.82951,
#   'volumeUsd24h': 197828.82951,
#   'priceHigh24h': 3.955e-05,
#   'priceLow24h': 2.838e-05},
#  {'name': 'XRPBULL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 3.076e-05,
#   'bid': 3.109e-05,
#   'ask': 3.148e-05,
#   'price': 3.109e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.032204515272244355,
#   'change24h': -0.11851431811738021,
#   'changeBod': -0.10916905444126075,
#   'quoteVolume24h': 15021.98292,
#   'volumeUsd24h': 15020.480721708,
#   'priceHigh24h': 3.938e-05,
#   'priceLow24h': 2.868e-05},
#  {'name': 'XRPHALF/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 13551.0,
#   'bid': 12845.0,
#   'ask': 12870.5,
#   'price': 12870.5,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPHALF',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0044484332930112775,
#   'change24h': -0.019763899466869763,
#   'changeBod': -0.01736906397923347,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 13551.0,
#   'priceLow24h': 12704.5},
#  {'name': 'XRPHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 45.745,
#   'bid': 45.29,
#   'ask': 45.415,
#   'price': 45.415,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.007213903158815171,
#   'change24h': 0.03853190029727876,
#   'changeBod': 0.03829446730681298,
#   'quoteVolume24h': 7564.439595,
#   'volumeUsd24h': 7564.439595,
#   'priceHigh24h': 46.37,
#   'priceLow24h': 41.94},
#  {'name': 'XTZBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000000.0,
#   'minProvideSize': 1000000.0,
#   'last': 1.4e-07,
#   'bid': 1.3e-07,
#   'ask': 1.5e-07,
#   'price': 1.4e-07,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.06666666666666667,
#   'change24h': 0.07692307692307693,
#   'changeBod': 0.07692307692307693,
#   'quoteVolume24h': 49.15,
#   'volumeUsd24h': 49.15,
#   'priceHigh24h': 1.5e-07,
#   'priceLow24h': 1.2e-07},
#  {'name': 'XTZBEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000000.0,
#   'minProvideSize': 1000000.0,
#   'last': 1.3e-07,
#   'bid': 1.3e-07,
#   'ask': 1.5e-07,
#   'price': 1.3e-07,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -0.07142857142857142,
#   'change24h': 0.0,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 1.4e-07,
#   'priceLow24h': 1.3e-07},
#  {'name': 'XTZBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 1.931e-05,
#   'bid': 1.824e-05,
#   'ask': 1.986e-05,
#   'price': 1.931e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': 0.030416221985058698,
#   'changeBod': -0.04970472440944882,
#   'quoteVolume24h': 130.2149,
#   'volumeUsd24h': 130.2149,
#   'priceHigh24h': 2.352e-05,
#   'priceLow24h': 1.8e-05},
#  {'name': 'XTZBULL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 2.042e-05,
#   'bid': 1.811e-05,
#   'ask': 1.988e-05,
#   'price': 1.988e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.023160061760164694,
#   'change24h': -0.03213242453748783,
#   'changeBod': -0.02644466209598433,
#   'quoteVolume24h': 9.8016,
#   'volumeUsd24h': 9.80061984,
#   'priceHigh24h': 2.168e-05,
#   'priceLow24h': 1.863e-05},
#  {'name': 'XTZHALF/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.25,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 6423.0,
#   'bid': 6204.0,
#   'ask': 6241.75,
#   'price': 6241.75,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZHALF',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0034564527149230336,
#   'change24h': -0.005774131889136668,
#   'changeBod': -0.007749781416421588,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 6423.0,
#   'priceLow24h': 6183.5},
#  {'name': 'XTZHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 65.03,
#   'bid': 65.535,
#   'ask': 66.315,
#   'price': 65.535,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.006744468020612307,
#   'change24h': 0.007765646624634784,
#   'changeBod': 0.007765646624634784,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 66.785,
#   'priceLow24h': 62.22},
#  {'name': 'ZECBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 100.0,
#   'minProvideSize': 100.0,
#   'last': 0.002866,
#   'bid': 0.002761,
#   'ask': 0.002858,
#   'price': 0.002858,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ZECBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.020714285714285713,
#   'change24h': 0.05617147080561715,
#   'changeBod': 0.07686510926902788,
#   'quoteVolume24h': 149.8556,
#   'volumeUsd24h': 149.8556,
#   'priceHigh24h': 0.002898,
#   'priceLow24h': 0.002277},
#  {'name': 'ZECBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 0.0001674,
#   'bid': 0.0001641,
#   'ask': 0.0001674,
#   'price': 0.0001674,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ZECBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.011480362537764351,
#   'change24h': -0.05557122708039492,
#   'changeBod': -0.06714962385065477,
#   'quoteVolume24h': 1889.87925,
#   'volumeUsd24h': 1889.87925,
#   'priceHigh24h': 0.00020525,
#   'priceLow24h': 0.0001595}]

# %%
df = pd.DataFrame(data)
df = df.set_index('name')
df
# Out:
#               enabled  postOnly  priceIncrement  sizeIncrement  \
# name
# 1INCH-PERP       True     False    1.000000e-04        1.00000
# 1INCH-0930       True     False    1.000000e-04        1.00000
# 1INCH-1230       True     False    1.000000e-04        1.00000
# 1INCH/USD        True     False    1.000000e-04        1.00000
# AAPL-0930        True     False    1.000000e-02        0.01000
# ...               ...       ...             ...            ...
# XTZBULL/USDT     True     False    1.000000e-08    10000.00000
# XTZHALF/USD      True     False    2.500000e-01        0.00001
# XTZHEDGE/USD     True     False    5.000000e-03        0.00100
# ZECBEAR/USD      True     False    1.000000e-06      100.00000
# ZECBULL/USD      True     False    5.000000e-08     1000.00000
#
#               minProvideSize         last          bid          ask  \
# name
# 1INCH-PERP           1.00000     0.608600     0.608500     0.608600
# 1INCH-0930           1.00000     0.603800     0.603600     0.606200
# 1INCH-1230           1.00000     0.590100     0.587300     0.590300
# 1INCH/USD            1.00000     0.609300     0.608800     0.609300
# AAPL-0930            0.01000   152.000000   151.920000   152.590000
# ...                      ...          ...          ...          ...
# XTZBULL/USDT     10000.00000     0.000020     0.000018     0.000020
# XTZHALF/USD          0.00001  6423.000000  6204.000000  6241.750000
# XTZHEDGE/USD         0.00100    65.030000    65.535000    66.315000
# ZECBEAR/USD        100.00000     0.002866     0.002761     0.002858
# ZECBULL/USD       1000.00000     0.000167     0.000164     0.000167
#
#                     price    type  ... highLeverageFeeExempt  \
# name                               ...
# 1INCH-PERP       0.608600  future  ...                 False
# 1INCH-0930       0.603800  future  ...                 False
# 1INCH-1230       0.590100  future  ...                 False
# 1INCH/USD        0.609300    spot  ...                  True
# AAPL-0930      152.000000  future  ...                 False
# ...                   ...     ...  ...                   ...
# XTZBULL/USDT     0.000020    spot  ...                  True
# XTZHALF/USD   6241.750000    spot  ...                  True
# XTZHEDGE/USD    65.535000    spot  ...                  True
# ZECBEAR/USD      0.002858    spot  ...                  True
# ZECBULL/USD      0.000167    spot  ...                  True
#
#              largeOrderThreshold  change1h change24h changeBod  \
# name
# 1INCH-PERP                 350.0  0.005950 -0.019968 -0.023741
# 1INCH-0930                 350.0  0.000000 -0.022819 -0.025972
# 1INCH-1230                 350.0  0.008029 -0.020418 -0.024144
# 1INCH/USD                  280.0  0.005944 -0.018841 -0.023558
# AAPL-0930                  350.0  0.000000  0.004826  0.004826
# ...                          ...       ...       ...       ...
# XTZBULL/USDT               196.0  0.023160 -0.032132 -0.026445
# XTZHALF/USD                280.0  0.003456 -0.005774 -0.007750
# XTZHEDGE/USD               280.0 -0.006744  0.007766  0.007766
# ZECBEAR/USD                280.0  0.020714  0.056171  0.076865
# ZECBULL/USD                280.0  0.011480 -0.055571 -0.067150
#
#               quoteVolume24h  volumeUsd24h  priceHigh24h  priceLow24h  \
# name
# 1INCH-PERP      6.046161e+06  6.046161e+06      0.648500     0.601300
# 1INCH-0930      7.966094e+03  7.966094e+03      0.644800     0.598500
# 1INCH-1230      1.065107e+03  1.065107e+03      0.625800     0.582900
# 1INCH/USD       1.466167e+06  1.466167e+06      0.648200     0.601300
# AAPL-0930       1.562595e+04  1.562595e+04    154.690000   150.240000
# ...                      ...           ...           ...          ...
# XTZBULL/USDT    9.801600e+00  9.800620e+00      0.000022     0.000019
# XTZHALF/USD     0.000000e+00  0.000000e+00   6423.000000  6183.500000
# XTZHEDGE/USD    0.000000e+00  0.000000e+00     66.785000    62.220000
# ZECBEAR/USD     1.498556e+02  1.498556e+02      0.002898     0.002277
# ZECBULL/USD     1.889879e+03  1.889879e+03      0.000205     0.000160
#
#               tokenizedEquity
# name
# 1INCH-PERP                NaN
# 1INCH-0930                NaN
# 1INCH-1230                NaN
# 1INCH/USD                 NaN
# AAPL-0930                True
# ...                       ...
# XTZBULL/USDT              NaN
# XTZHALF/USD               NaN
# XTZHEDGE/USD              NaN
# ZECBEAR/USD               NaN
# ZECBULL/USD               NaN
#
# [935 rows x 26 columns]

# %%
market_name = 'ETH/USD'
path = f'/markets/{market_name}'
url = api_url + path
url
# Out:
# 'https://ftx.com/api/markets/ETH/USD'

# %%
res = requests.get(url).json()
df = pd.DataFrame(res)['result']
df
# Out:
# ask                              1331.1
# baseCurrency                        ETH
# bid                              1331.0
# change1h                       0.008028
# change24h                      0.001279
# changeBod                     -0.001725
# enabled                            True
# futureType                         None
# highLeverageFeeExempt              True
# isEtfMarket                       False
# largeOrderThreshold              2400.0
# last                             1330.9
# minProvideSize                    0.001
# name                            ETH/USD
# postOnly                          False
# price                            1331.0
# priceHigh24h                     1400.4
# priceIncrement                      0.1
# priceLow24h                      1303.8
# quoteCurrency                       USD
# quoteVolume24h           600225066.3053
# restricted                        False
# sizeIncrement                     0.001
# type                               spot
# underlying                         None
# volumeUsd24h             600225066.3053
# Name: result, dtype: object

# %%
resolution = 86400*30
start_time = datetime.datetime(2022, 2, 1).timestamp()
path = f'/markets/{market_name}/candles?resolution={resolution}&start_time={start_time}'
# Out:
# 1643691600.0

# %%
url = api_url + path
res = requests.get(url).json()
df = pd.DataFrame(res['result'])
df
# Out:
#                    startTime          time    open    high     low   close  \
# 0  2022-02-02T00:00:00+00:00  1.643760e+12  2789.1  3286.5  2301.1  2948.6
# 1  2022-03-03T00:00:00+00:00  1.646266e+12  2948.7  3483.7  2444.7  3456.4
# 2  2022-04-02T00:00:00+00:00  1.648858e+12  3456.4  3581.4  2714.5  2824.4
# 3  2022-05-02T00:00:00+00:00  1.651450e+12  2824.4  2966.5  1700.0  1940.3
# 4  2022-06-01T00:00:00+00:00  1.654042e+12  1940.3  1971.5   880.0  1070.4
# 5  2022-07-01T00:00:00+00:00  1.656634e+12  1070.4  1785.6  1005.3  1697.7
# 6  2022-07-31T00:00:00+00:00  1.659226e+12  1697.7  2030.9  1421.9  1551.7
# 7  2022-08-30T00:00:00+00:00  1.661818e+12  1551.7  1790.3  1219.2  1308.6
#
#          volume
# 0  1.296256e+10
# 1  1.074473e+10
# 2  9.239965e+09
# 3  1.633315e+10
# 4  1.655756e+10
# 5  1.575615e+10
# 6  1.740227e+10
# 7  1.816807e+10

# %%
df['date'] = pd.to_datetime(df['startTime'])
df = df.set_index('date')
df = df.drop(columns = ['startTime', 'time'])
df.head()
# Out:
#                              open    high     low   close        volume
# date
# 2022-02-02 00:00:00+00:00  2789.1  2812.4  2600.0  2681.2  4.713406e+08
# 2022-02-03 00:00:00+00:00  2681.2  2725.3  2577.0  2696.4  4.444618e+08
# 2022-02-04 00:00:00+00:00  2696.4  2998.0  2673.1  2997.4  5.573329e+08
# 2022-02-05 00:00:00+00:00  2997.4  3062.7  2961.4  3015.1  3.270660e+08
# 2022-02-06 00:00:00+00:00  3015.1  3078.8  2953.0  3057.5  2.242591e+08
